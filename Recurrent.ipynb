# %% [markdown]
# Used a naive RNN cell and then a lstm cell to predict the minimum and maximum temperature using a given data of weather report during the World War 2. The data for this project was taken from Kaggle.

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import time

# %%
def rnn_step(x, h_prev, Wxh, bh, Whh, Why, by, activation=tf.nn.relu):
    
    hidden = tf.matmul(x, Wxh)
    state = tf.matmul(h_prev, Whh)
    h = tf.nn.tanh(hidden + state + bh)
    out = activation(tf.matmul(h, Why) + by)
    return h, out

# %%
def rnn_forward(x, h_ini, Wxh, bh, Whh, Why, by, activation=tf.nn.leaky_relu):
    
    if x.ndim is not 3:
        x = tf.expand_dims(x, 0)
    
    t = x.shape[1]
    h = np.copy(h_ini)
    for i in range(t):
        xs = x[:, i, :]
        if xs.ndim is not 2:
            xs = tf.expand_dims(xs, 0)
        h, out = rnn_step(xs, h, Wxh, bh, Whh, Why, by, activation)
    return out

# %%
def seperate_labels(x, window, step):
    
    assert window > step
    
    final_x = x[0:window-1]
    final_x = tf.expand_dims(final_x, axis=0)
    
    final_y = x[window]
    final_y = tf.expand_dims(final_y, axis=0)
    
    for i in range(step, len(x)-window, step):
        xt = x[i:i+window-1]
        xt = tf.expand_dims(xt, axis=0)
        final_x = tf.concat([final_x, xt], axis=0)
        
        yt = x[i+window]
        yt = tf.expand_dims(yt, axis=0)
        final_y = tf.concat([final_y, yt], axis=0)
        
    return final_x, final_y

# %%
def normalize(data, mean=None, std=None):
    if mean==None:
        mean = tf.reduce_mean(data, axis=0)
    if std==None:
        std = tf.reduce_max(data, axis=0)-tf.reduce_min(data, axis=0)
    normalized = (data - mean)/std + 1
    return normalized, mean, std

# %%
def inverse_transform(data, mean, std):
    out = (data-1) * std + mean
    return out

# %%
data = pd.read_csv('./data/weatherww2/Summary of Weather.csv', usecols=['MaxTemp', 'MinTemp']).values
stations = pd.read_csv('./data/weatherww2/Summary of Weather.csv', usecols=['STA']).values
stations= stations.reshape(-1)
idx = tf.where(stations==10001)
idx = tf.reshape(idx, [-1])
data = data[idx]
print(data.shape)
# Out:
# (1157, 2)

# %%
train_data = data[0:800]
cv_data = data[800:1000]
test_data = data[1000:1150]

train_data, train_mean, train_std = normalize(train_data)
cv_data,_,_ = normalize(cv_data, train_mean, train_std)

X, Y = seperate_labels(train_data, window=4, step=1)
x_cv, y_cv = seperate_labels(cv_data, 4, 1)

print(X.shape, Y.shape)
# Out:
# (796, 3, 2) (796, 2)

# %%
num_samples, time_step, num_features = X.shape
hidden_size = 2
out_size = Y.shape[-1]
learning_rate = 0.001
epochs = 1000
mini_batch = 10

# %%
h_ini = [[0.,0.]]

Wxh = tf.Variable(np.random.randn(num_features, hidden_size)*0.1)
Whh = tf.Variable(np.random.randn(hidden_size, hidden_size)*0.1)
bh = tf.Variable(np.random.randn(hidden_size)*0.1)

Why = tf.Variable(np.random.randn(hidden_size, out_size)*0.1)
by = tf.Variable(np.random.randn(out_size)*0.1)

optimizer = tf.keras.optimizers.Adam(learning_rate)
variables = [Wxh, Whh, bh, Why, by]

print(Wxh, Whh)
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float64, numpy=
# array([[-0.10927166,  0.02234396],
#        [ 0.02736561,  0.0582876 ]])> <tf.Variable 'Variable:0' shape=(2, 2) dtype=float64, numpy=
# array([[-0.09989175,  0.0429998 ],
#        [-0.06979307, -0.17064172]])>

# %%
X, Y = seperate_labels(train_data, window=4, step=1)
x_cv, y_cv = seperate_labels(cv_data, 4, 1)
learning_rate = 0.001
mini_batch = 10
for i in range(epochs):
    print("EPOCH", i)
    start = time.time()
    total_loss = 0.
    for j in range(0, num_samples-mini_batch, mini_batch):
        xs = X[j:j+mini_batch,:,:]
        ys = Y[j:j+mini_batch]
        with tf.GradientTape(persistent=True, watch_accessed_variables=False) as t:
            t.watch([Wxh, Whh, bh, Why, by])
            out = rnn_forward(xs, h_ini, Wxh, bh, Whh, Why, by)
            loss = tf.reduce_sum(tf.math.square(out-ys))/mini_batch
            total_loss += loss
        Wxh.assign_sub(learning_rate*t.gradient(loss,Wxh))
        Whh.assign_sub(learning_rate*t.gradient(loss,Whh))
        bh.assign_sub(learning_rate*t.gradient(loss,bh))
        Why.assign_sub(learning_rate*t.gradient(loss,Why))
        by.assign_sub(learning_rate*t.gradient(loss,by))
        del t
    end = time.time()
    mean_loss = total_loss/(num_samples//mini_batch)
    print("loss at end of EPOCH: %0.4f" % mean_loss)
    print("time taken: {:0.2f}s".format(end-start))
    y_predict = rnn_forward(x_cv, h_ini, Wxh, bh, Whh, Why, by)
    cv_loss = tf.reduce_sum(tf.math.square(y_predict-y_cv))/len(x_cv)
    print("validation loss:", cv_loss.numpy())
    print("Done with EPOCH")
# Out:
# EPOCH 0
# loss at end of EPOCH: 1.2217
# time taken: 1.31s
# validation loss: 1.390253390270983
# Done with EPOCH
# EPOCH 1
# loss at end of EPOCH: 0.8428
# time taken: 1.30s
# validation loss: 0.9951154483460689
# Done with EPOCH
# EPOCH 2
# loss at end of EPOCH: 0.5677
# time taken: 1.31s
# validation loss: 0.7003188186683963
# Done with EPOCH
# EPOCH 3
# loss at end of EPOCH: 0.3736
# time taken: 1.33s
# validation loss: 0.48656407636532645
# Done with EPOCH
# EPOCH 4
# loss at end of EPOCH: 0.2423
# time taken: 1.28s
# validation loss: 0.33702246996332624
# Done with EPOCH
# EPOCH 5
# loss at end of EPOCH: 0.1579
# time taken: 1.31s
# validation loss: 0.23593957485637168
# Done with EPOCH
# EPOCH 6
# loss at end of EPOCH: 0.1062
# time taken: 1.31s
# validation loss: 0.1693954228778298
# Done with EPOCH
# EPOCH 7
# loss at end of EPOCH: 0.0759
# time taken: 1.29s
# validation loss: 0.12626447669151597
# Done with EPOCH
# EPOCH 8
# loss at end of EPOCH: 0.0588
# time taken: 1.27s
# validation loss: 0.09844335778750735
# Done with EPOCH
# EPOCH 9
# loss at end of EPOCH: 0.0494
# time taken: 1.30s
# validation loss: 0.08042876399909264
# Done with EPOCH
# EPOCH 10
# loss at end of EPOCH: 0.0444
# time taken: 1.31s
# validation loss: 0.06865094991195082
# Done with EPOCH
# EPOCH 11
# loss at end of EPOCH: 0.0418
# time taken: 1.28s
# validation loss: 0.06085226037426183
# Done with EPOCH
# EPOCH 12
# loss at end of EPOCH: 0.0404
# time taken: 1.25s
# validation loss: 0.05561786284198375
# Done with EPOCH
# EPOCH 13
# loss at end of EPOCH: 0.0397
# time taken: 1.31s
# validation loss: 0.052058737800491854
# Done with EPOCH
# EPOCH 14
# loss at end of EPOCH: 0.0394
# time taken: 1.30s
# validation loss: 0.049610360648954875
# Done with EPOCH
# EPOCH 15
# loss at end of EPOCH: 0.0392
# time taken: 1.28s
# validation loss: 0.04790888139050731
# Done with EPOCH
# EPOCH 16
# loss at end of EPOCH: 0.0391
# time taken: 1.28s
# validation loss: 0.046715895363112006
# Done with EPOCH
# EPOCH 17
# loss at end of EPOCH: 0.0390
# time taken: 1.28s
# validation loss: 0.04587267045620379
# Done with EPOCH
# EPOCH 18
# loss at end of EPOCH: 0.0390
# time taken: 1.32s
# validation loss: 0.04527199597795484
# Done with EPOCH
# EPOCH 19
# loss at end of EPOCH: 0.0390
# time taken: 1.28s
# validation loss: 0.04484058081448288
# Done with EPOCH
# EPOCH 20
# loss at end of EPOCH: 0.0390
# time taken: 1.29s
# validation loss: 0.04452783314557521
# Done with EPOCH
# EPOCH 21
# loss at end of EPOCH: 0.0390
# time taken: 1.31s
# validation loss: 0.04429856584181522
# Done with EPOCH
# EPOCH 22
# loss at end of EPOCH: 0.0389
# time taken: 1.28s
# validation loss: 0.044128166142380965
# Done with EPOCH
# EPOCH 23
# loss at end of EPOCH: 0.0389
# time taken: 1.29s
# validation loss: 0.04399934542215147
# Done with EPOCH
# EPOCH 24
# loss at end of EPOCH: 0.0389
# time taken: 1.29s
# validation loss: 0.043899922881914424
# Done with EPOCH
# EPOCH 25
# loss at end of EPOCH: 0.0389
# time taken: 1.28s
# validation loss: 0.04382129814958325
# Done with EPOCH
# EPOCH 26
# loss at end of EPOCH: 0.0389
# time taken: 1.26s
# validation loss: 0.04375738999379792
# Done with EPOCH
# EPOCH 27
# loss at end of EPOCH: 0.0389
# time taken: 1.27s
# validation loss: 0.043703894343072966
# Done with EPOCH
# EPOCH 28
# loss at end of EPOCH: 0.0388
# time taken: 1.28s
# validation loss: 0.043657763176746064
# Done with EPOCH
# EPOCH 29
# loss at end of EPOCH: 0.0388
# time taken: 1.31s
# validation loss: 0.04361683733316862
# Done with EPOCH
# EPOCH 30
# loss at end of EPOCH: 0.0388
# time taken: 1.29s
# validation loss: 0.043579587169858214
# Done with EPOCH
# EPOCH 31
# loss at end of EPOCH: 0.0388
# time taken: 1.30s
# validation loss: 0.043544929102010535
# Done with EPOCH
# EPOCH 32
# loss at end of EPOCH: 0.0388
# time taken: 1.28s
# validation loss: 0.043512095679054584
# Done with EPOCH
# EPOCH 33
# loss at end of EPOCH: 0.0387
# time taken: 1.28s
# validation loss: 0.04348054351321114
# Done with EPOCH
# EPOCH 34
# loss at end of EPOCH: 0.0387
# time taken: 1.28s
# validation loss: 0.04344988800708551
# Done with EPOCH
# EPOCH 35
# loss at end of EPOCH: 0.0387
# time taken: 1.28s
# validation loss: 0.04341985707225122
# Done with EPOCH
# EPOCH 36
# loss at end of EPOCH: 0.0387
# time taken: 1.29s
# validation loss: 0.043390258313319816
# Done with EPOCH
# EPOCH 37
# loss at end of EPOCH: 0.0387
# time taken: 1.29s
# validation loss: 0.04336095576260215
# Done with EPOCH
# EPOCH 38
# loss at end of EPOCH: 0.0386
# time taken: 1.28s
# validation loss: 0.043331853389437215
# Done with EPOCH
# EPOCH 39
# loss at end of EPOCH: 0.0386
# time taken: 1.28s
# validation loss: 0.043302883414961794
# Done with EPOCH
# EPOCH 40
# loss at end of EPOCH: 0.0386
# time taken: 1.30s
# validation loss: 0.04327399803501203
# Done with EPOCH
# EPOCH 41
# loss at end of EPOCH: 0.0386
# time taken: 1.30s
# validation loss: 0.043245163559608925
# Done with EPOCH
# EPOCH 42
# loss at end of EPOCH: 0.0386
# time taken: 1.35s
# validation loss: 0.04321635626544037
# Done with EPOCH
# EPOCH 43
# loss at end of EPOCH: 0.0385
# time taken: 1.28s
# validation loss: 0.043187559462173265
# Done with EPOCH
# EPOCH 44
# loss at end of EPOCH: 0.0385
# time taken: 1.29s
# validation loss: 0.04315876141853373
# Done with EPOCH
# EPOCH 45
# loss at end of EPOCH: 0.0385
# time taken: 1.28s
# validation loss: 0.043129953897094966
# Done with EPOCH
# EPOCH 46
# loss at end of EPOCH: 0.0385
# time taken: 1.27s
# validation loss: 0.043101131119805715
# Done with EPOCH
# EPOCH 47
# loss at end of EPOCH: 0.0385
# time taken: 1.30s
# validation loss: 0.04307228903816535
# Done with EPOCH
# EPOCH 48
# loss at end of EPOCH: 0.0384
# time taken: 1.28s
# validation loss: 0.04304342481872915
# Done with EPOCH
# EPOCH 49
# loss at end of EPOCH: 0.0384
# time taken: 1.30s
# validation loss: 0.04301453648072476
# Done with EPOCH
# EPOCH 50
# loss at end of EPOCH: 0.0384
# time taken: 1.29s
# validation loss: 0.042985622641041485
# Done with EPOCH
# EPOCH 51
# loss at end of EPOCH: 0.0384
# time taken: 1.25s
# validation loss: 0.042956682334959716
# Done with EPOCH
# EPOCH 52
# loss at end of EPOCH: 0.0384
# time taken: 1.29s
# validation loss: 0.04292771489026418
# Done with EPOCH
# EPOCH 53
# loss at end of EPOCH: 0.0383
# time taken: 1.26s
# validation loss: 0.0428987198389473
# Done with EPOCH
# EPOCH 54
# loss at end of EPOCH: 0.0383
# time taken: 1.33s
# validation loss: 0.04286969685536303
# Done with EPOCH
# EPOCH 55
# loss at end of EPOCH: 0.0383
# time taken: 1.29s
# validation loss: 0.04284064571296753
# Done with EPOCH
# EPOCH 56
# loss at end of EPOCH: 0.0383
# time taken: 1.35s
# validation loss: 0.042811566254111
# Done with EPOCH
# EPOCH 57
# loss at end of EPOCH: 0.0383
# time taken: 1.44s
# validation loss: 0.04278245836897978
# Done with EPOCH
# EPOCH 58
# loss at end of EPOCH: 0.0382
# time taken: 1.68s
# validation loss: 0.042753321980945246
# Done with EPOCH
# EPOCH 59
# loss at end of EPOCH: 0.0382
# time taken: 1.75s
# validation loss: 0.042724157036394116
# Done with EPOCH
# EPOCH 60
# loss at end of EPOCH: 0.0382
# time taken: 1.41s
# validation loss: 0.042694963497686644
# Done with EPOCH
# EPOCH 61
# loss at end of EPOCH: 0.0382
# time taken: 1.31s
# validation loss: 0.04266574133829349
# Done with EPOCH
# EPOCH 62
# loss at end of EPOCH: 0.0382
# time taken: 1.29s
# validation loss: 0.04263649053944856
# Done with EPOCH
# EPOCH 63
# loss at end of EPOCH: 0.0381
# time taken: 1.29s
# validation loss: 0.04260721108785516
# Done with EPOCH
# EPOCH 64
# loss at end of EPOCH: 0.0381
# time taken: 1.27s
# validation loss: 0.042577902974117114
# Done with EPOCH
# EPOCH 65
# loss at end of EPOCH: 0.0381
# time taken: 1.28s
# validation loss: 0.04254856619167447
# Done with EPOCH
# EPOCH 66
# loss at end of EPOCH: 0.0381
# time taken: 1.28s
# validation loss: 0.042519200736084714
# Done with EPOCH
# EPOCH 67
# loss at end of EPOCH: 0.0381
# time taken: 1.30s
# validation loss: 0.04248980660453947
# Done with EPOCH
# EPOCH 68
# loss at end of EPOCH: 0.0380
# time taken: 1.31s
# validation loss: 0.0424603837955446
# Done with EPOCH
# EPOCH 69
# loss at end of EPOCH: 0.0380
# time taken: 1.28s
# validation loss: 0.04243093230870859
# Done with EPOCH
# EPOCH 70
# loss at end of EPOCH: 0.0380
# time taken: 1.29s
# validation loss: 0.042401452144605375
# Done with EPOCH
# EPOCH 71
# loss at end of EPOCH: 0.0380
# time taken: 1.28s
# validation loss: 0.042371943304687715
# Done with EPOCH
# EPOCH 72
# loss at end of EPOCH: 0.0380
# time taken: 1.29s
# validation loss: 0.042342405791231975
# Done with EPOCH
# EPOCH 73
# loss at end of EPOCH: 0.0379
# time taken: 1.29s
# validation loss: 0.04231283960730601
# Done with EPOCH
# EPOCH 74
# loss at end of EPOCH: 0.0379
# time taken: 1.27s
# validation loss: 0.04228324475675053
# Done with EPOCH
# EPOCH 75
# loss at end of EPOCH: 0.0379
# time taken: 1.29s
# validation loss: 0.04225362124416921
# Done with EPOCH
# EPOCH 76
# loss at end of EPOCH: 0.0379
# time taken: 1.26s
# validation loss: 0.042223969074924865
# Done with EPOCH
# EPOCH 77
# loss at end of EPOCH: 0.0378
# time taken: 1.25s
# validation loss: 0.04219428825513882
# Done with EPOCH
# EPOCH 78
# loss at end of EPOCH: 0.0378
# time taken: 1.27s
# validation loss: 0.042164578791692435
# Done with EPOCH
# EPOCH 79
# loss at end of EPOCH: 0.0378
# time taken: 1.29s
# validation loss: 0.042134840692228843
# Done with EPOCH
# EPOCH 80
# loss at end of EPOCH: 0.0378
# time taken: 1.30s
# validation loss: 0.04210507396515591
# Done with EPOCH
# EPOCH 81
# loss at end of EPOCH: 0.0378
# time taken: 1.28s
# validation loss: 0.04207527861964996
# Done with EPOCH
# EPOCH 82
# loss at end of EPOCH: 0.0377
# time taken: 1.28s
# validation loss: 0.04204545466565739
# Done with EPOCH
# EPOCH 83
# loss at end of EPOCH: 0.0377
# time taken: 1.29s
# validation loss: 0.04201560211389808
# Done with EPOCH
# EPOCH 84
# loss at end of EPOCH: 0.0377
# time taken: 1.27s
# validation loss: 0.041985720975867856
# Done with EPOCH
# EPOCH 85
# loss at end of EPOCH: 0.0377
# time taken: 1.29s
# validation loss: 0.04195581126384003
# Done with EPOCH
# EPOCH 86
# loss at end of EPOCH: 0.0377
# time taken: 1.26s
# validation loss: 0.04192587299086844
# Done with EPOCH
# EPOCH 87
# loss at end of EPOCH: 0.0376
# time taken: 1.27s
# validation loss: 0.041895906170788325
# Done with EPOCH
# EPOCH 88
# loss at end of EPOCH: 0.0376
# time taken: 1.28s
# validation loss: 0.041865910818218804
# Done with EPOCH
# EPOCH 89
# loss at end of EPOCH: 0.0376
# time taken: 1.27s
# validation loss: 0.04183588694856387
# Done with EPOCH
# EPOCH 90
# loss at end of EPOCH: 0.0376
# time taken: 1.27s
# validation loss: 0.0418058345780137
# Done with EPOCH
# EPOCH 91
# loss at end of EPOCH: 0.0376
# time taken: 1.28s
# validation loss: 0.04177575372354612
# Done with EPOCH
# EPOCH 92
# loss at end of EPOCH: 0.0375
# time taken: 1.27s
# validation loss: 0.041745644402927835
# Done with EPOCH
# EPOCH 93
# loss at end of EPOCH: 0.0375
# time taken: 1.32s
# validation loss: 0.041715506634715765
# Done with EPOCH
# EPOCH 94
# loss at end of EPOCH: 0.0375
# time taken: 1.26s
# validation loss: 0.0416853404382576
# Done with EPOCH
# EPOCH 95
# loss at end of EPOCH: 0.0375
# time taken: 1.29s
# validation loss: 0.04165514583369297
# Done with EPOCH
# EPOCH 96
# loss at end of EPOCH: 0.0375
# time taken: 1.28s
# validation loss: 0.04162492284195454
# Done with EPOCH
# EPOCH 97
# loss at end of EPOCH: 0.0374
# time taken: 1.27s
# validation loss: 0.04159467148476936
# Done with EPOCH
# EPOCH 98
# loss at end of EPOCH: 0.0374
# time taken: 1.30s
# validation loss: 0.04156439178465872
# Done with EPOCH
# EPOCH 99
# loss at end of EPOCH: 0.0374
# time taken: 1.27s
# validation loss: 0.041534083764939986
# Done with EPOCH
# EPOCH 100
# loss at end of EPOCH: 0.0374
# time taken: 1.28s
# validation loss: 0.04150374744972727
# Done with EPOCH
# EPOCH 101
# loss at end of EPOCH: 0.0373
# time taken: 1.26s
# validation loss: 0.04147338286393225
# Done with EPOCH
# EPOCH 102
# loss at end of EPOCH: 0.0373
# time taken: 1.27s
# validation loss: 0.0414429900332646
# Done with EPOCH
# EPOCH 103
# loss at end of EPOCH: 0.0373
# time taken: 1.27s
# validation loss: 0.04141256898423367
# Done with EPOCH
# EPOCH 104
# loss at end of EPOCH: 0.0373
# time taken: 1.27s
# validation loss: 0.041382119744148314
# Done with EPOCH
# EPOCH 105
# loss at end of EPOCH: 0.0373
# time taken: 1.30s
# validation loss: 0.04135164234111872
# Done with EPOCH
# EPOCH 106
# loss at end of EPOCH: 0.0372
# time taken: 1.30s
# validation loss: 0.041321136804056795
# Done with EPOCH
# EPOCH 107
# loss at end of EPOCH: 0.0372
# time taken: 1.29s
# validation loss: 0.041290603162676465
# Done with EPOCH
# EPOCH 108
# loss at end of EPOCH: 0.0372
# time taken: 1.29s
# validation loss: 0.04126004144749531
# Done with EPOCH
# EPOCH 109
# loss at end of EPOCH: 0.0372
# time taken: 1.28s
# validation loss: 0.04122945168983464
# Done with EPOCH
# EPOCH 110
# loss at end of EPOCH: 0.0372
# time taken: 1.31s
# validation loss: 0.041198833921820756
# Done with EPOCH
# EPOCH 111
# loss at end of EPOCH: 0.0371
# time taken: 1.28s
# validation loss: 0.04116818817638557
# Done with EPOCH
# EPOCH 112
# loss at end of EPOCH: 0.0371
# time taken: 1.28s
# validation loss: 0.041137514487267435
# Done with EPOCH
# EPOCH 113
# loss at end of EPOCH: 0.0371
# time taken: 1.25s
# validation loss: 0.04110681288901116
# Done with EPOCH
# EPOCH 114
# loss at end of EPOCH: 0.0371
# time taken: 1.27s
# validation loss: 0.04107608341697031
# Done with EPOCH
# EPOCH 115
# loss at end of EPOCH: 0.0370
# time taken: 1.28s
# validation loss: 0.041045326107306435
# Done with EPOCH
# EPOCH 116
# loss at end of EPOCH: 0.0370
# time taken: 1.30s
# validation loss: 0.04101454099699077
# Done with EPOCH
# EPOCH 117
# loss at end of EPOCH: 0.0370
# time taken: 1.27s
# validation loss: 0.04098372812380416
# Done with EPOCH
# EPOCH 118
# loss at end of EPOCH: 0.0370
# time taken: 1.29s
# validation loss: 0.040952887526338265
# Done with EPOCH
# EPOCH 119
# loss at end of EPOCH: 0.0370
# time taken: 1.29s
# validation loss: 0.04092201924399659
# Done with EPOCH
# EPOCH 120
# loss at end of EPOCH: 0.0369
# time taken: 1.26s
# validation loss: 0.04089112331699418
# Done with EPOCH
# EPOCH 121
# loss at end of EPOCH: 0.0369
# time taken: 1.29s
# validation loss: 0.04086019978635909
# Done with EPOCH
# EPOCH 122
# loss at end of EPOCH: 0.0369
# time taken: 1.27s
# validation loss: 0.04082924869393318
# Done with EPOCH
# EPOCH 123
# loss at end of EPOCH: 0.0369
# time taken: 1.30s
# validation loss: 0.04079827008237187
# Done with EPOCH
# EPOCH 124
# loss at end of EPOCH: 0.0369
# time taken: 1.30s
# validation loss: 0.04076726399514579
# Done with EPOCH
# EPOCH 125
# loss at end of EPOCH: 0.0368
# time taken: 1.27s
# validation loss: 0.04073623047654101
# Done with EPOCH
# EPOCH 126
# loss at end of EPOCH: 0.0368
# time taken: 1.28s
# validation loss: 0.040705169571659455
# Done with EPOCH
# EPOCH 127
# loss at end of EPOCH: 0.0368
# time taken: 1.30s
# validation loss: 0.040674081326419864
# Done with EPOCH
# EPOCH 128
# loss at end of EPOCH: 0.0368
# time taken: 1.32s
# validation loss: 0.04064296578755834
# Done with EPOCH
# EPOCH 129
# loss at end of EPOCH: 0.0367
# time taken: 1.28s
# validation loss: 0.04061182300262866
# Done with EPOCH
# EPOCH 130
# loss at end of EPOCH: 0.0367
# time taken: 1.31s
# validation loss: 0.04058065302000359
# Done with EPOCH
# EPOCH 131
# loss at end of EPOCH: 0.0367
# time taken: 1.29s
# validation loss: 0.04054945588887437
# Done with EPOCH
# EPOCH 132
# loss at end of EPOCH: 0.0367
# time taken: 1.27s
# validation loss: 0.04051823165925209
# Done with EPOCH
# EPOCH 133
# loss at end of EPOCH: 0.0367
# time taken: 1.34s
# validation loss: 0.04048698038196842
# Done with EPOCH
# EPOCH 134
# loss at end of EPOCH: 0.0366
# time taken: 1.33s
# validation loss: 0.04045570210867541
# Done with EPOCH
# EPOCH 135
# loss at end of EPOCH: 0.0366
# time taken: 1.28s
# validation loss: 0.04042439689184669
# Done with EPOCH
# EPOCH 136
# loss at end of EPOCH: 0.0366
# time taken: 1.29s
# validation loss: 0.04039306478477737
# Done with EPOCH
# EPOCH 137
# loss at end of EPOCH: 0.0366
# time taken: 1.28s
# validation loss: 0.040361705841585147
# Done with EPOCH
# EPOCH 138
# loss at end of EPOCH: 0.0366
# time taken: 1.29s
# validation loss: 0.04033032011721014
# Done with EPOCH
# EPOCH 139
# loss at end of EPOCH: 0.0365
# time taken: 1.31s
# validation loss: 0.04029890766741633
# Done with EPOCH
# EPOCH 140
# loss at end of EPOCH: 0.0365
# time taken: 1.29s
# validation loss: 0.04026746854879112
# Done with EPOCH
# EPOCH 141
# loss at end of EPOCH: 0.0365
# time taken: 1.28s
# validation loss: 0.04023600281874652
# Done with EPOCH
# EPOCH 142
# loss at end of EPOCH: 0.0365
# time taken: 1.27s
# validation loss: 0.04020451053551894
# Done with EPOCH
# EPOCH 143
# loss at end of EPOCH: 0.0364
# time taken: 1.29s
# validation loss: 0.040172991758169935
# Done with EPOCH
# EPOCH 144
# loss at end of EPOCH: 0.0364
# time taken: 1.27s
# validation loss: 0.04014144654658675
# Done with EPOCH
# EPOCH 145
# loss at end of EPOCH: 0.0364
# time taken: 1.27s
# validation loss: 0.04010987496148244
# Done with EPOCH
# EPOCH 146
# loss at end of EPOCH: 0.0364
# time taken: 1.27s
# validation loss: 0.04007827706439659
# Done with EPOCH
# EPOCH 147
# loss at end of EPOCH: 0.0364
# time taken: 1.26s
# validation loss: 0.040046652917695276
# Done with EPOCH
# EPOCH 148
# loss at end of EPOCH: 0.0363
# time taken: 1.28s
# validation loss: 0.040015002584571975
# Done with EPOCH
# EPOCH 149
# loss at end of EPOCH: 0.0363
# time taken: 1.27s
# validation loss: 0.03998332612904777
# Done with EPOCH
# EPOCH 150
# loss at end of EPOCH: 0.0363
# time taken: 1.25s
# validation loss: 0.039951623615971044
# Done with EPOCH
# EPOCH 151
# loss at end of EPOCH: 0.0363
# time taken: 1.30s
# validation loss: 0.0399198951110183
# Done with EPOCH
# EPOCH 152
# loss at end of EPOCH: 0.0362
# time taken: 1.32s
# validation loss: 0.03988814068069515
# Done with EPOCH
# EPOCH 153
# loss at end of EPOCH: 0.0362
# time taken: 1.28s
# validation loss: 0.039856360392335505
# Done with EPOCH
# EPOCH 154
# loss at end of EPOCH: 0.0362
# time taken: 1.28s
# validation loss: 0.03982455431410227
# Done with EPOCH
# EPOCH 155
# loss at end of EPOCH: 0.0362
# time taken: 1.27s
# validation loss: 0.03979272251498744
# Done with EPOCH
# EPOCH 156
# loss at end of EPOCH: 0.0362
# time taken: 1.28s
# validation loss: 0.03976086506481294
# Done with EPOCH
# EPOCH 157
# loss at end of EPOCH: 0.0361
# time taken: 1.28s
# validation loss: 0.039728982034230254
# Done with EPOCH
# EPOCH 158
# loss at end of EPOCH: 0.0361
# time taken: 1.29s
# validation loss: 0.03969707349472087
# Done with EPOCH
# EPOCH 159
# loss at end of EPOCH: 0.0361
# time taken: 1.31s
# validation loss: 0.039665139518596446
# Done with EPOCH
# EPOCH 160
# loss at end of EPOCH: 0.0361
# time taken: 1.28s
# validation loss: 0.03963318017899909
# Done with EPOCH
# EPOCH 161
# loss at end of EPOCH: 0.0360
# time taken: 1.28s
# validation loss: 0.039601195549901325
# Done with EPOCH
# EPOCH 162
# loss at end of EPOCH: 0.0360
# time taken: 1.28s
# validation loss: 0.03956918570610667
# Done with EPOCH
# EPOCH 163
# loss at end of EPOCH: 0.0360
# time taken: 1.27s
# validation loss: 0.039537150723249
# Done with EPOCH
# EPOCH 164
# loss at end of EPOCH: 0.0360
# time taken: 1.29s
# validation loss: 0.03950509067779343
# Done with EPOCH
# EPOCH 165
# loss at end of EPOCH: 0.0360
# time taken: 1.28s
# validation loss: 0.039473005647036125
# Done with EPOCH
# EPOCH 166
# loss at end of EPOCH: 0.0359
# time taken: 1.29s
# validation loss: 0.03944089570910446
# Done with EPOCH
# EPOCH 167
# loss at end of EPOCH: 0.0359
# time taken: 1.27s
# validation loss: 0.039408760942957026
# Done with EPOCH
# EPOCH 168
# loss at end of EPOCH: 0.0359
# time taken: 1.28s
# validation loss: 0.039376601428383604
# Done with EPOCH
# EPOCH 169
# loss at end of EPOCH: 0.0359
# time taken: 1.28s
# validation loss: 0.039344417246005216
# Done with EPOCH
# EPOCH 170
# loss at end of EPOCH: 0.0358
# time taken: 1.29s
# validation loss: 0.039312208477274416
# Done with EPOCH
# EPOCH 171
# loss at end of EPOCH: 0.0358
# time taken: 1.27s
# validation loss: 0.03927997520447521
# Done with EPOCH
# EPOCH 172
# loss at end of EPOCH: 0.0358
# time taken: 1.26s
# validation loss: 0.039247717510722285
# Done with EPOCH
# EPOCH 173
# loss at end of EPOCH: 0.0358
# time taken: 1.27s
# validation loss: 0.03921543547996229
# Done with EPOCH
# EPOCH 174
# loss at end of EPOCH: 0.0358
# time taken: 1.26s
# validation loss: 0.039183129196973115
# Done with EPOCH
# EPOCH 175
# loss at end of EPOCH: 0.0357
# time taken: 1.27s
# validation loss: 0.039150798747363075
# Done with EPOCH
# EPOCH 176
# loss at end of EPOCH: 0.0357
# time taken: 1.28s
# validation loss: 0.03911844421757229
# Done with EPOCH
# EPOCH 177
# loss at end of EPOCH: 0.0357
# time taken: 1.31s
# validation loss: 0.039086065694871885
# Done with EPOCH
# EPOCH 178
# loss at end of EPOCH: 0.0357
# time taken: 1.28s
# validation loss: 0.03905366326736329
# Done with EPOCH
# EPOCH 179
# loss at end of EPOCH: 0.0356
# time taken: 1.29s
# validation loss: 0.03902123702397899
# Done with EPOCH
# EPOCH 180
# loss at end of EPOCH: 0.0356
# time taken: 1.27s
# validation loss: 0.03898878705448168
# Done with EPOCH
# EPOCH 181
# loss at end of EPOCH: 0.0356
# time taken: 1.28s
# validation loss: 0.03895631344946508
# Done with EPOCH
# EPOCH 182
# loss at end of EPOCH: 0.0356
# time taken: 1.28s
# validation loss: 0.038923816300352465
# Done with EPOCH
# EPOCH 183
# loss at end of EPOCH: 0.0356
# time taken: 1.29s
# validation loss: 0.038891295699397185
# Done with EPOCH
# EPOCH 184
# loss at end of EPOCH: 0.0355
# time taken: 1.28s
# validation loss: 0.03885875173968222
# Done with EPOCH
# EPOCH 185
# loss at end of EPOCH: 0.0355
# time taken: 1.26s
# validation loss: 0.03882618451512015
# Done with EPOCH
# EPOCH 186
# loss at end of EPOCH: 0.0355
# time taken: 1.26s
# validation loss: 0.03879359412045252
# Done with EPOCH
# EPOCH 187
# loss at end of EPOCH: 0.0355
# time taken: 1.25s
# validation loss: 0.03876098065124996
# Done with EPOCH
# EPOCH 188
# loss at end of EPOCH: 0.0354
# time taken: 1.27s
# validation loss: 0.03872834420391142
# Done with EPOCH
# EPOCH 189
# loss at end of EPOCH: 0.0354
# time taken: 1.28s
# validation loss: 0.03869568487566411
# Done with EPOCH
# EPOCH 190
# loss at end of EPOCH: 0.0354
# time taken: 1.31s
# validation loss: 0.03866300276456313
# Done with EPOCH
# EPOCH 191
# loss at end of EPOCH: 0.0354
# time taken: 1.28s
# validation loss: 0.03863029796949079
# Done with EPOCH
# EPOCH 192
# loss at end of EPOCH: 0.0353
# time taken: 1.30s
# validation loss: 0.0385975705901568
# Done with EPOCH
# EPOCH 193
# loss at end of EPOCH: 0.0353
# time taken: 1.27s
# validation loss: 0.03856482072709722
# Done with EPOCH
# EPOCH 194
# loss at end of EPOCH: 0.0353
# time taken: 1.26s
# validation loss: 0.03853204848167414
# Done with EPOCH
# EPOCH 195
# loss at end of EPOCH: 0.0353
# time taken: 1.31s
# validation loss: 0.03849925395607579
# Done with EPOCH
# EPOCH 196
# loss at end of EPOCH: 0.0353
# time taken: 1.27s
# validation loss: 0.038466437253315326
# Done with EPOCH
# EPOCH 197
# loss at end of EPOCH: 0.0352
# time taken: 1.27s
# validation loss: 0.03843359847723068
# Done with EPOCH
# EPOCH 198
# loss at end of EPOCH: 0.0352
# time taken: 1.28s
# validation loss: 0.03840073773248399
# Done with EPOCH
# EPOCH 199
# loss at end of EPOCH: 0.0352
# time taken: 1.27s
# validation loss: 0.038367855124561
# Done with EPOCH
# EPOCH 200
# loss at end of EPOCH: 0.0352
# time taken: 1.29s
# validation loss: 0.0383349507597705
# Done with EPOCH
# EPOCH 201
# loss at end of EPOCH: 0.0351
# time taken: 1.32s
# validation loss: 0.03830202474524377
# Done with EPOCH
# EPOCH 202
# loss at end of EPOCH: 0.0351
# time taken: 1.29s
# validation loss: 0.03826907718893407
# Done with EPOCH
# EPOCH 203
# loss at end of EPOCH: 0.0351
# time taken: 1.30s
# validation loss: 0.038236108199615655
# Done with EPOCH
# EPOCH 204
# loss at end of EPOCH: 0.0351
# time taken: 1.30s
# validation loss: 0.03820311788688349
# Done with EPOCH
# EPOCH 205
# loss at end of EPOCH: 0.0351
# time taken: 1.27s
# validation loss: 0.03817010636115214
# Done with EPOCH
# EPOCH 206
# loss at end of EPOCH: 0.0350
# time taken: 1.29s
# validation loss: 0.038137073733655644
# Done with EPOCH
# EPOCH 207
# loss at end of EPOCH: 0.0350
# time taken: 1.27s
# validation loss: 0.03810402011644638
# Done with EPOCH
# EPOCH 208
# loss at end of EPOCH: 0.0350
# time taken: 1.29s
# validation loss: 0.038070945622394235
# Done with EPOCH
# EPOCH 209
# loss at end of EPOCH: 0.0350
# time taken: 1.29s
# validation loss: 0.038037850365186275
# Done with EPOCH
# EPOCH 210
# loss at end of EPOCH: 0.0349
# time taken: 1.26s
# validation loss: 0.0380047344593255
# Done with EPOCH
# EPOCH 211
# loss at end of EPOCH: 0.0349
# time taken: 1.28s
# validation loss: 0.03797159802013011
# Done with EPOCH
# EPOCH 212
# loss at end of EPOCH: 0.0349
# time taken: 1.30s
# validation loss: 0.03793844116373304
# Done with EPOCH
# EPOCH 213
# loss at end of EPOCH: 0.0349
# time taken: 1.26s
# validation loss: 0.03790526400708053
# Done with EPOCH
# EPOCH 214
# loss at end of EPOCH: 0.0348
# time taken: 1.29s
# validation loss: 0.03787206666793169
# Done with EPOCH
# EPOCH 215
# loss at end of EPOCH: 0.0348
# time taken: 1.28s
# validation loss: 0.03783884926485718
# Done with EPOCH
# EPOCH 216
# loss at end of EPOCH: 0.0348
# time taken: 1.28s
# validation loss: 0.03780561191723862
# Done with EPOCH
# EPOCH 217
# loss at end of EPOCH: 0.0348
# time taken: 1.29s
# validation loss: 0.03777235474526778
# Done with EPOCH
# EPOCH 218
# loss at end of EPOCH: 0.0348
# time taken: 1.28s
# validation loss: 0.0377390778699446
# Done with EPOCH
# EPOCH 219
# loss at end of EPOCH: 0.0347
# time taken: 1.27s
# validation loss: 0.03770578141307766
# Done with EPOCH
# EPOCH 220
# loss at end of EPOCH: 0.0347
# time taken: 1.27s
# validation loss: 0.037672465497281905
# Done with EPOCH
# EPOCH 221
# loss at end of EPOCH: 0.0347
# time taken: 1.27s
# validation loss: 0.03763913024597803
# Done with EPOCH
# EPOCH 222
# loss at end of EPOCH: 0.0347
# time taken: 1.29s
# validation loss: 0.03760577578339209
# Done with EPOCH
# EPOCH 223
# loss at end of EPOCH: 0.0346
# time taken: 1.31s
# validation loss: 0.03757240223455275
# Done with EPOCH
# EPOCH 224
# loss at end of EPOCH: 0.0346
# time taken: 1.27s
# validation loss: 0.03753900972529211
# Done with EPOCH
# EPOCH 225
# loss at end of EPOCH: 0.0346
# time taken: 1.27s
# validation loss: 0.03750559838224261
# Done with EPOCH
# EPOCH 226
# loss at end of EPOCH: 0.0346
# time taken: 1.31s
# validation loss: 0.03747216833283743
# Done with EPOCH
# EPOCH 227
# loss at end of EPOCH: 0.0345
# time taken: 1.34s
# validation loss: 0.037438719705308474
# Done with EPOCH
# EPOCH 228
# loss at end of EPOCH: 0.0345
# time taken: 1.38s
# validation loss: 0.037405252628685215
# Done with EPOCH
# EPOCH 229
# loss at end of EPOCH: 0.0345
# time taken: 1.32s
# validation loss: 0.037371767232793854
# Done with EPOCH
# EPOCH 230
# loss at end of EPOCH: 0.0345
# time taken: 1.40s
# validation loss: 0.03733826364825551
# Done with EPOCH
# EPOCH 231
# loss at end of EPOCH: 0.0345
# time taken: 1.39s
# validation loss: 0.03730474200648496
# Done with EPOCH
# EPOCH 232
# loss at end of EPOCH: 0.0344
# time taken: 1.38s
# validation loss: 0.03727120243969003
# Done with EPOCH
# EPOCH 233
# loss at end of EPOCH: 0.0344
# time taken: 1.38s
# validation loss: 0.037237645080869235
# Done with EPOCH
# EPOCH 234
# loss at end of EPOCH: 0.0344
# time taken: 1.39s
# validation loss: 0.03720407006381067
# Done with EPOCH
# EPOCH 235
# loss at end of EPOCH: 0.0344
# time taken: 1.41s
# validation loss: 0.03717047752309113
# Done with EPOCH
# EPOCH 236
# loss at end of EPOCH: 0.0343
# time taken: 1.42s
# validation loss: 0.03713686759407416
# Done with EPOCH
# EPOCH 237
# loss at end of EPOCH: 0.0343
# time taken: 1.42s
# validation loss: 0.03710324041290888
# Done with EPOCH
# EPOCH 238
# loss at end of EPOCH: 0.0343
# time taken: 1.38s
# validation loss: 0.037069596116527895
# Done with EPOCH
# EPOCH 239
# loss at end of EPOCH: 0.0343
# time taken: 1.42s
# validation loss: 0.03703593484264693
# Done with EPOCH
# EPOCH 240
# loss at end of EPOCH: 0.0342
# time taken: 1.44s
# validation loss: 0.03700225672976212
# Done with EPOCH
# EPOCH 241
# loss at end of EPOCH: 0.0342
# time taken: 1.41s
# validation loss: 0.03696856191714893
# Done with EPOCH
# EPOCH 242
# loss at end of EPOCH: 0.0342
# time taken: 1.45s
# validation loss: 0.036934850544860835
# Done with EPOCH
# EPOCH 243
# loss at end of EPOCH: 0.0342
# time taken: 1.43s
# validation loss: 0.03690112275372704
# Done with EPOCH
# EPOCH 244
# loss at end of EPOCH: 0.0342
# time taken: 1.41s
# validation loss: 0.036867378685351365
# Done with EPOCH
# EPOCH 245
# loss at end of EPOCH: 0.0341
# time taken: 1.40s
# validation loss: 0.03683361848211067
# Done with EPOCH
# EPOCH 246
# loss at end of EPOCH: 0.0341
# time taken: 1.42s
# validation loss: 0.036799842287152204
# Done with EPOCH
# EPOCH 247
# loss at end of EPOCH: 0.0341
# time taken: 1.43s
# validation loss: 0.036766050244393056
# Done with EPOCH
# EPOCH 248
# loss at end of EPOCH: 0.0341
# time taken: 1.43s
# validation loss: 0.03673224249851779
# Done with EPOCH
# EPOCH 249
# loss at end of EPOCH: 0.0340
# time taken: 1.43s
# validation loss: 0.03669841919497686
# Done with EPOCH
# EPOCH 250
# loss at end of EPOCH: 0.0340
# time taken: 1.43s
# validation loss: 0.03666458047998443
# Done with EPOCH
# EPOCH 251
# loss at end of EPOCH: 0.0340
# time taken: 1.39s
# validation loss: 0.03663072650051735
# Done with EPOCH
# EPOCH 252
# loss at end of EPOCH: 0.0340
# time taken: 1.38s
# validation loss: 0.036596857404312046
# Done with EPOCH
# EPOCH 253
# loss at end of EPOCH: 0.0339
# time taken: 1.44s
# validation loss: 0.03656297333986373
# Done with EPOCH
# EPOCH 254
# loss at end of EPOCH: 0.0339
# time taken: 1.40s
# validation loss: 0.03652907445642406
# Done with EPOCH
# EPOCH 255
# loss at end of EPOCH: 0.0339
# time taken: 1.38s
# validation loss: 0.036495160903998874
# Done with EPOCH
# EPOCH 256
# loss at end of EPOCH: 0.0339
# time taken: 1.38s
# validation loss: 0.036461232833347186
# Done with EPOCH
# EPOCH 257
# loss at end of EPOCH: 0.0339
# time taken: 1.39s
# validation loss: 0.0364272903959779
# Done with EPOCH
# EPOCH 258
# loss at end of EPOCH: 0.0338
# time taken: 1.35s
# validation loss: 0.03639333374414858
# Done with EPOCH
# EPOCH 259
# loss at end of EPOCH: 0.0338
# time taken: 1.33s
# validation loss: 0.036359363030863644
# Done with EPOCH
# EPOCH 260
# loss at end of EPOCH: 0.0338
# time taken: 1.35s
# validation loss: 0.03632537840987132
# Done with EPOCH
# EPOCH 261
# loss at end of EPOCH: 0.0338
# time taken: 1.31s
# validation loss: 0.036291380035661985
# Done with EPOCH
# EPOCH 262
# loss at end of EPOCH: 0.0337
# time taken: 1.34s
# validation loss: 0.03625736806346678
# Done with EPOCH
# EPOCH 263
# loss at end of EPOCH: 0.0337
# time taken: 1.35s
# validation loss: 0.03622334264925411
# Done with EPOCH
# EPOCH 264
# loss at end of EPOCH: 0.0337
# time taken: 1.34s
# validation loss: 0.0361893039497283
# Done with EPOCH
# EPOCH 265
# loss at end of EPOCH: 0.0337
# time taken: 1.39s
# validation loss: 0.036155252122327
# Done with EPOCH
# EPOCH 266
# loss at end of EPOCH: 0.0336
# time taken: 1.35s
# validation loss: 0.03612118732521914
# Done with EPOCH
# EPOCH 267
# loss at end of EPOCH: 0.0336
# time taken: 1.34s
# validation loss: 0.03608710971730291
# Done with EPOCH
# EPOCH 268
# loss at end of EPOCH: 0.0336
# time taken: 1.32s
# validation loss: 0.03605301945820253
# Done with EPOCH
# EPOCH 269
# loss at end of EPOCH: 0.0336
# time taken: 1.32s
# validation loss: 0.03601891670826698
# Done with EPOCH
# EPOCH 270
# loss at end of EPOCH: 0.0335
# time taken: 1.31s
# validation loss: 0.0359848016285667
# Done with EPOCH
# EPOCH 271
# loss at end of EPOCH: 0.0335
# time taken: 1.27s
# validation loss: 0.03595067438089175
# Done with EPOCH
# EPOCH 272
# loss at end of EPOCH: 0.0335
# time taken: 1.29s
# validation loss: 0.035916535127749095
# Done with EPOCH
# EPOCH 273
# loss at end of EPOCH: 0.0335
# time taken: 1.27s
# validation loss: 0.035882384032360645
# Done with EPOCH
# EPOCH 274
# loss at end of EPOCH: 0.0335
# time taken: 1.30s
# validation loss: 0.03584822125866004
# Done with EPOCH
# EPOCH 275
# loss at end of EPOCH: 0.0334
# time taken: 1.31s
# validation loss: 0.03581404697129071
# Done with EPOCH
# EPOCH 276
# loss at end of EPOCH: 0.0334
# time taken: 1.30s
# validation loss: 0.03577986133560279
# Done with EPOCH
# EPOCH 277
# loss at end of EPOCH: 0.0334
# time taken: 1.31s
# validation loss: 0.03574566451765135
# Done with EPOCH
# EPOCH 278
# loss at end of EPOCH: 0.0334
# time taken: 1.29s
# validation loss: 0.03571145668419284
# Done with EPOCH
# EPOCH 279
# loss at end of EPOCH: 0.0333
# time taken: 1.27s
# validation loss: 0.035677238002683125
# Done with EPOCH
# EPOCH 280
# loss at end of EPOCH: 0.0333
# time taken: 1.29s
# validation loss: 0.035643008641274225
# Done with EPOCH
# EPOCH 281
# loss at end of EPOCH: 0.0333
# time taken: 1.26s
# validation loss: 0.035608768768812554
# Done with EPOCH
# EPOCH 282
# loss at end of EPOCH: 0.0333
# time taken: 1.30s
# validation loss: 0.035574518554835115
# Done with EPOCH
# EPOCH 283
# loss at end of EPOCH: 0.0332
# time taken: 1.30s
# validation loss: 0.035540258169567754
# Done with EPOCH
# EPOCH 284
# loss at end of EPOCH: 0.0332
# time taken: 1.28s
# validation loss: 0.03550598778392125
# Done with EPOCH
# EPOCH 285
# loss at end of EPOCH: 0.0332
# time taken: 1.28s
# validation loss: 0.03547170756948987
# Done with EPOCH
# EPOCH 286
# loss at end of EPOCH: 0.0332
# time taken: 1.28s
# validation loss: 0.03543741769854693
# Done with EPOCH
# EPOCH 287
# loss at end of EPOCH: 0.0331
# time taken: 1.29s
# validation loss: 0.035403118344043416
# Done with EPOCH
# EPOCH 288
# loss at end of EPOCH: 0.0331
# time taken: 1.28s
# validation loss: 0.03536880967960404
# Done with EPOCH
# EPOCH 289
# loss at end of EPOCH: 0.0331
# time taken: 1.29s
# validation loss: 0.03533449187952507
# Done with EPOCH
# EPOCH 290
# loss at end of EPOCH: 0.0331
# time taken: 1.40s
# validation loss: 0.035300165118770745
# Done with EPOCH
# EPOCH 291
# loss at end of EPOCH: 0.0331
# time taken: 1.46s
# validation loss: 0.03526582957297045
# Done with EPOCH
# EPOCH 292
# loss at end of EPOCH: 0.0330
# time taken: 1.45s
# validation loss: 0.035231485418415975
# Done with EPOCH
# EPOCH 293
# loss at end of EPOCH: 0.0330
# time taken: 1.46s
# validation loss: 0.03519713283205822
# Done with EPOCH
# EPOCH 294
# loss at end of EPOCH: 0.0330
# time taken: 1.49s
# validation loss: 0.03516277199150417
# Done with EPOCH
# EPOCH 295
# loss at end of EPOCH: 0.0330
# time taken: 1.47s
# validation loss: 0.03512840307501355
# Done with EPOCH
# EPOCH 296
# loss at end of EPOCH: 0.0329
# time taken: 1.47s
# validation loss: 0.03509402626149597
# Done with EPOCH
# EPOCH 297
# loss at end of EPOCH: 0.0329
# time taken: 1.42s
# validation loss: 0.03505964173050805
# Done with EPOCH
# EPOCH 298
# loss at end of EPOCH: 0.0329
# time taken: 1.35s
# validation loss: 0.035025249662249194
# Done with EPOCH
# EPOCH 299
# loss at end of EPOCH: 0.0329
# time taken: 1.29s
# validation loss: 0.0349908502375596
# Done with EPOCH
# EPOCH 300
# loss at end of EPOCH: 0.0328
# time taken: 1.29s
# validation loss: 0.034956443637916015
# Done with EPOCH
# EPOCH 301
# loss at end of EPOCH: 0.0328
# time taken: 1.28s
# validation loss: 0.03492203004542888
# Done with EPOCH
# EPOCH 302
# loss at end of EPOCH: 0.0328
# time taken: 1.27s
# validation loss: 0.03488760964283943
# Done with EPOCH
# EPOCH 303
# loss at end of EPOCH: 0.0328
# time taken: 1.27s
# validation loss: 0.03485318261351521
# Done with EPOCH
# EPOCH 304
# loss at end of EPOCH: 0.0328
# time taken: 1.32s
# validation loss: 0.03481874914144726
# Done with EPOCH
# EPOCH 305
# loss at end of EPOCH: 0.0327
# time taken: 1.30s
# validation loss: 0.03478430941124762
# Done with EPOCH
# EPOCH 306
# loss at end of EPOCH: 0.0327
# time taken: 1.29s
# validation loss: 0.03474986360814435
# Done with EPOCH
# EPOCH 307
# loss at end of EPOCH: 0.0327
# time taken: 1.26s
# validation loss: 0.03471541191797903
# Done with EPOCH
# EPOCH 308
# loss at end of EPOCH: 0.0327
# time taken: 1.29s
# validation loss: 0.03468095452720308
# Done with EPOCH
# EPOCH 309
# loss at end of EPOCH: 0.0326
# time taken: 1.27s
# validation loss: 0.03464649162287369
# Done with EPOCH
# EPOCH 310
# loss at end of EPOCH: 0.0326
# time taken: 1.25s
# validation loss: 0.03461202339265106
# Done with EPOCH
# EPOCH 311
# loss at end of EPOCH: 0.0326
# time taken: 1.29s
# validation loss: 0.03457755002479441
# Done with EPOCH
# EPOCH 312
# loss at end of EPOCH: 0.0326
# time taken: 1.28s
# validation loss: 0.03454307170815821
# Done with EPOCH
# EPOCH 313
# loss at end of EPOCH: 0.0325
# time taken: 1.26s
# validation loss: 0.03450858863218909
# Done with EPOCH
# EPOCH 314
# loss at end of EPOCH: 0.0325
# time taken: 1.26s
# validation loss: 0.034474100986921365
# Done with EPOCH
# EPOCH 315
# loss at end of EPOCH: 0.0325
# time taken: 1.31s
# validation loss: 0.03443960896297375
# Done with EPOCH
# EPOCH 316
# loss at end of EPOCH: 0.0325
# time taken: 1.32s
# validation loss: 0.03440511275154591
# Done with EPOCH
# EPOCH 317
# loss at end of EPOCH: 0.0324
# time taken: 1.32s
# validation loss: 0.03437061254441407
# Done with EPOCH
# EPOCH 318
# loss at end of EPOCH: 0.0324
# time taken: 1.29s
# validation loss: 0.034336108533927476
# Done with EPOCH
# EPOCH 319
# loss at end of EPOCH: 0.0324
# time taken: 1.28s
# validation loss: 0.034301600913004944
# Done with EPOCH
# EPOCH 320
# loss at end of EPOCH: 0.0324
# time taken: 1.27s
# validation loss: 0.03426708987513031
# Done with EPOCH
# EPOCH 321
# loss at end of EPOCH: 0.0324
# time taken: 1.27s
# validation loss: 0.034232575614348774
# Done with EPOCH
# EPOCH 322
# loss at end of EPOCH: 0.0323
# time taken: 1.28s
# validation loss: 0.03419805832526333
# Done with EPOCH
# EPOCH 323
# loss at end of EPOCH: 0.0323
# time taken: 1.27s
# validation loss: 0.03416353820303059
# Done with EPOCH
# EPOCH 324
# loss at end of EPOCH: 0.0323
# time taken: 1.28s
# validation loss: 0.03412901544335662
# Done with EPOCH
# EPOCH 325
# loss at end of EPOCH: 0.0323
# time taken: 1.26s
# validation loss: 0.034094490242492836
# Done with EPOCH
# EPOCH 326
# loss at end of EPOCH: 0.0322
# time taken: 1.27s
# validation loss: 0.03405996279723254
# Done with EPOCH
# EPOCH 327
# loss at end of EPOCH: 0.0322
# time taken: 1.31s
# validation loss: 0.034025433304906455
# Done with EPOCH
# EPOCH 328
# loss at end of EPOCH: 0.0322
# time taken: 1.29s
# validation loss: 0.033990901963378416
# Done with EPOCH
# EPOCH 329
# loss at end of EPOCH: 0.0322
# time taken: 1.28s
# validation loss: 0.03395636897104183
# Done with EPOCH
# EPOCH 330
# loss at end of EPOCH: 0.0321
# time taken: 1.28s
# validation loss: 0.03392183452681514
# Done with EPOCH
# EPOCH 331
# loss at end of EPOCH: 0.0321
# time taken: 1.29s
# validation loss: 0.03388729883013698
# Done with EPOCH
# EPOCH 332
# loss at end of EPOCH: 0.0321
# time taken: 1.27s
# validation loss: 0.033852762080963654
# Done with EPOCH
# EPOCH 333
# loss at end of EPOCH: 0.0321
# time taken: 1.28s
# validation loss: 0.03381822447976356
# Done with EPOCH
# EPOCH 334
# loss at end of EPOCH: 0.0320
# time taken: 1.28s
# validation loss: 0.033783686227512245
# Done with EPOCH
# EPOCH 335
# loss at end of EPOCH: 0.0320
# time taken: 1.28s
# validation loss: 0.033749147525690595
# Done with EPOCH
# EPOCH 336
# loss at end of EPOCH: 0.0320
# time taken: 1.29s
# validation loss: 0.033714608576277914
# Done with EPOCH
# EPOCH 337
# loss at end of EPOCH: 0.0320
# time taken: 1.26s
# validation loss: 0.03368006958174884
# Done with EPOCH
# EPOCH 338
# loss at end of EPOCH: 0.0320
# time taken: 1.30s
# validation loss: 0.03364553074506913
# Done with EPOCH
# EPOCH 339
# loss at end of EPOCH: 0.0319
# time taken: 1.30s
# validation loss: 0.03361099226969016
# Done with EPOCH
# EPOCH 340
# loss at end of EPOCH: 0.0319
# time taken: 1.28s
# validation loss: 0.03357645435954557
# Done with EPOCH
# EPOCH 341
# loss at end of EPOCH: 0.0319
# time taken: 1.26s
# validation loss: 0.03354191721904635
# Done with EPOCH
# EPOCH 342
# loss at end of EPOCH: 0.0319
# time taken: 1.28s
# validation loss: 0.0335073810530762
# Done with EPOCH
# EPOCH 343
# loss at end of EPOCH: 0.0318
# time taken: 1.27s
# validation loss: 0.033472846066986965
# Done with EPOCH
# EPOCH 344
# loss at end of EPOCH: 0.0318
# time taken: 1.28s
# validation loss: 0.03343831246659465
# Done with EPOCH
# EPOCH 345
# loss at end of EPOCH: 0.0318
# time taken: 1.27s
# validation loss: 0.03340378045817397
# Done with EPOCH
# EPOCH 346
# loss at end of EPOCH: 0.0318
# time taken: 1.29s
# validation loss: 0.033369250248454205
# Done with EPOCH
# EPOCH 347
# loss at end of EPOCH: 0.0317
# time taken: 1.27s
# validation loss: 0.03333472204461459
# Done with EPOCH
# EPOCH 348
# loss at end of EPOCH: 0.0317
# time taken: 1.26s
# validation loss: 0.0333001960542795
# Done with EPOCH
# EPOCH 349
# loss at end of EPOCH: 0.0317
# time taken: 1.25s
# validation loss: 0.03326567248551396
# Done with EPOCH
# EPOCH 350
# loss at end of EPOCH: 0.0317
# time taken: 1.27s
# validation loss: 0.03323115154681822
# Done with EPOCH
# EPOCH 351
# loss at end of EPOCH: 0.0317
# time taken: 1.30s
# validation loss: 0.03319663344712396
# Done with EPOCH
# EPOCH 352
# loss at end of EPOCH: 0.0316
# time taken: 1.29s
# validation loss: 0.03316211839578835
# Done with EPOCH
# EPOCH 353
# loss at end of EPOCH: 0.0316
# time taken: 1.29s
# validation loss: 0.03312760660259066
# Done with EPOCH
# EPOCH 354
# loss at end of EPOCH: 0.0316
# time taken: 1.28s
# validation loss: 0.03309309827772646
# Done with EPOCH
# EPOCH 355
# loss at end of EPOCH: 0.0316
# time taken: 1.29s
# validation loss: 0.033058593631802254
# Done with EPOCH
# EPOCH 356
# loss at end of EPOCH: 0.0315
# time taken: 1.27s
# validation loss: 0.03302409287583207
# Done with EPOCH
# EPOCH 357
# loss at end of EPOCH: 0.0315
# time taken: 1.29s
# validation loss: 0.032989596221231314
# Done with EPOCH
# EPOCH 358
# loss at end of EPOCH: 0.0315
# time taken: 1.30s
# validation loss: 0.032955103879812
# Done with EPOCH
# EPOCH 359
# loss at end of EPOCH: 0.0315
# time taken: 1.28s
# validation loss: 0.03292061606377841
# Done with EPOCH
# EPOCH 360
# loss at end of EPOCH: 0.0314
# time taken: 1.26s
# validation loss: 0.03288613298572122
# Done with EPOCH
# EPOCH 361
# loss at end of EPOCH: 0.0314
# time taken: 1.26s
# validation loss: 0.032851654858612966
# Done with EPOCH
# EPOCH 362
# loss at end of EPOCH: 0.0314
# time taken: 1.26s
# validation loss: 0.03281718189580295
# Done with EPOCH
# EPOCH 363
# loss at end of EPOCH: 0.0314
# time taken: 1.30s
# validation loss: 0.032782714311012186
# Done with EPOCH
# EPOCH 364
# loss at end of EPOCH: 0.0314
# time taken: 1.29s
# validation loss: 0.032748252318327675
# Done with EPOCH
# EPOCH 365
# loss at end of EPOCH: 0.0313
# time taken: 1.30s
# validation loss: 0.032713796132198325
# Done with EPOCH
# EPOCH 366
# loss at end of EPOCH: 0.0313
# time taken: 1.27s
# validation loss: 0.03267934596742872
# Done with EPOCH
# EPOCH 367
# loss at end of EPOCH: 0.0313
# time taken: 1.28s
# validation loss: 0.03264490203917475
# Done with EPOCH
# EPOCH 368
# loss at end of EPOCH: 0.0313
# time taken: 1.26s
# validation loss: 0.03261046456293792
# Done with EPOCH
# EPOCH 369
# loss at end of EPOCH: 0.0312
# time taken: 1.30s
# validation loss: 0.03257603375455985
# Done with EPOCH
# EPOCH 370
# loss at end of EPOCH: 0.0312
# time taken: 1.29s
# validation loss: 0.032541609830217845
# Done with EPOCH
# EPOCH 371
# loss at end of EPOCH: 0.0312
# time taken: 1.29s
# validation loss: 0.032507193006419084
# Done with EPOCH
# EPOCH 372
# loss at end of EPOCH: 0.0312
# time taken: 1.26s
# validation loss: 0.032472783499994745
# Done with EPOCH
# EPOCH 373
# loss at end of EPOCH: 0.0311
# time taken: 1.28s
# validation loss: 0.03243838152809586
# Done with EPOCH
# EPOCH 374
# loss at end of EPOCH: 0.0311
# time taken: 1.31s
# validation loss: 0.032403987308187145
# Done with EPOCH
# EPOCH 375
# loss at end of EPOCH: 0.0311
# time taken: 1.29s
# validation loss: 0.03236960105804157
# Done with EPOCH
# EPOCH 376
# loss at end of EPOCH: 0.0311
# time taken: 1.28s
# validation loss: 0.0323352229957351
# Done with EPOCH
# EPOCH 377
# loss at end of EPOCH: 0.0311
# time taken: 1.27s
# validation loss: 0.032300853339641486
# Done with EPOCH
# EPOCH 378
# loss at end of EPOCH: 0.0310
# time taken: 1.30s
# validation loss: 0.03226649230842637
# Done with EPOCH
# EPOCH 379
# loss at end of EPOCH: 0.0310
# time taken: 1.28s
# validation loss: 0.03223214012104207
# Done with EPOCH
# EPOCH 380
# loss at end of EPOCH: 0.0310
# time taken: 1.25s
# validation loss: 0.03219779699672194
# Done with EPOCH
# EPOCH 381
# loss at end of EPOCH: 0.0310
# time taken: 1.31s
# validation loss: 0.0321634631549747
# Done with EPOCH
# EPOCH 382
# loss at end of EPOCH: 0.0309
# time taken: 1.26s
# validation loss: 0.03212913881557947
# Done with EPOCH
# EPOCH 383
# loss at end of EPOCH: 0.0309
# time taken: 1.27s
# validation loss: 0.032094824198579106
# Done with EPOCH
# EPOCH 384
# loss at end of EPOCH: 0.0309
# time taken: 1.26s
# validation loss: 0.03206051952427582
# Done with EPOCH
# EPOCH 385
# loss at end of EPOCH: 0.0309
# time taken: 1.28s
# validation loss: 0.03202622501322402
# Done with EPOCH
# EPOCH 386
# loss at end of EPOCH: 0.0308
# time taken: 1.30s
# validation loss: 0.031991940886226485
# Done with EPOCH
# EPOCH 387
# loss at end of EPOCH: 0.0308
# time taken: 1.31s
# validation loss: 0.03195766736432729
# Done with EPOCH
# EPOCH 388
# loss at end of EPOCH: 0.0308
# time taken: 1.30s
# validation loss: 0.031923404668806436
# Done with EPOCH
# EPOCH 389
# loss at end of EPOCH: 0.0308
# time taken: 1.29s
# validation loss: 0.03188915302117442
# Done with EPOCH
# EPOCH 390
# loss at end of EPOCH: 0.0308
# time taken: 1.29s
# validation loss: 0.031854912643166394
# Done with EPOCH
# EPOCH 391
# loss at end of EPOCH: 0.0307
# time taken: 1.28s
# validation loss: 0.031820683756736044
# Done with EPOCH
# EPOCH 392
# loss at end of EPOCH: 0.0307
# time taken: 1.28s
# validation loss: 0.031786466584050384
# Done with EPOCH
# EPOCH 393
# loss at end of EPOCH: 0.0307
# time taken: 1.28s
# validation loss: 0.03175226134748288
# Done with EPOCH
# EPOCH 394
# loss at end of EPOCH: 0.0307
# time taken: 1.30s
# validation loss: 0.031718068269609156
# Done with EPOCH
# EPOCH 395
# loss at end of EPOCH: 0.0306
# time taken: 1.28s
# validation loss: 0.03168388757319993
# Done with EPOCH
# EPOCH 396
# loss at end of EPOCH: 0.0306
# time taken: 1.28s
# validation loss: 0.03164971948121545
# Done with EPOCH
# EPOCH 397
# loss at end of EPOCH: 0.0306
# time taken: 1.28s
# validation loss: 0.031615564216799535
# Done with EPOCH
# EPOCH 398
# loss at end of EPOCH: 0.0306
# time taken: 1.28s
# validation loss: 0.031581422003274
# Done with EPOCH
# EPOCH 399
# loss at end of EPOCH: 0.0306
# time taken: 1.31s
# validation loss: 0.03154729306413253
# Done with EPOCH
# EPOCH 400
# loss at end of EPOCH: 0.0305
# time taken: 1.30s
# validation loss: 0.03151317762303468
# Done with EPOCH
# EPOCH 401
# loss at end of EPOCH: 0.0305
# time taken: 1.28s
# validation loss: 0.031479075903799586
# Done with EPOCH
# EPOCH 402
# loss at end of EPOCH: 0.0305
# time taken: 1.28s
# validation loss: 0.031444988130400676
# Done with EPOCH
# EPOCH 403
# loss at end of EPOCH: 0.0305
# time taken: 1.28s
# validation loss: 0.03141091452695897
# Done with EPOCH
# EPOCH 404
# loss at end of EPOCH: 0.0304
# time taken: 1.28s
# validation loss: 0.03137685531773729
# Done with EPOCH
# EPOCH 405
# loss at end of EPOCH: 0.0304
# time taken: 1.28s
# validation loss: 0.03134281072713435
# Done with EPOCH
# EPOCH 406
# loss at end of EPOCH: 0.0304
# time taken: 1.28s
# validation loss: 0.031308780979678645
# Done with EPOCH
# EPOCH 407
# loss at end of EPOCH: 0.0304
# time taken: 1.28s
# validation loss: 0.03127476630002221
# Done with EPOCH
# EPOCH 408
# loss at end of EPOCH: 0.0303
# time taken: 1.30s
# validation loss: 0.031240766912934658
# Done with EPOCH
# EPOCH 409
# loss at end of EPOCH: 0.0303
# time taken: 1.28s
# validation loss: 0.03120678304329654
# Done with EPOCH
# EPOCH 410
# loss at end of EPOCH: 0.0303
# time taken: 1.29s
# validation loss: 0.0311728149160943
# Done with EPOCH
# EPOCH 411
# loss at end of EPOCH: 0.0303
# time taken: 1.30s
# validation loss: 0.031138862756412856
# Done with EPOCH
# EPOCH 412
# loss at end of EPOCH: 0.0303
# time taken: 1.30s
# validation loss: 0.031104926789430453
# Done with EPOCH
# EPOCH 413
# loss at end of EPOCH: 0.0302
# time taken: 1.28s
# validation loss: 0.03107100724041176
# Done with EPOCH
# EPOCH 414
# loss at end of EPOCH: 0.0302
# time taken: 1.27s
# validation loss: 0.031037104334702338
# Done with EPOCH
# EPOCH 415
# loss at end of EPOCH: 0.0302
# time taken: 1.26s
# validation loss: 0.03100321829772123
# Done with EPOCH
# EPOCH 416
# loss at end of EPOCH: 0.0302
# time taken: 1.25s
# validation loss: 0.030969349354956183
# Done with EPOCH
# EPOCH 417
# loss at end of EPOCH: 0.0301
# time taken: 1.26s
# validation loss: 0.030935497731956276
# Done with EPOCH
# EPOCH 418
# loss at end of EPOCH: 0.0301
# time taken: 1.29s
# validation loss: 0.03090166365432616
# Done with EPOCH
# EPOCH 419
# loss at end of EPOCH: 0.0301
# time taken: 1.26s
# validation loss: 0.03086784734772018
# Done with EPOCH
# EPOCH 420
# loss at end of EPOCH: 0.0301
# time taken: 1.28s
# validation loss: 0.030834049037834592
# Done with EPOCH
# EPOCH 421
# loss at end of EPOCH: 0.0301
# time taken: 1.29s
# validation loss: 0.030800268950403026
# Done with EPOCH
# EPOCH 422
# loss at end of EPOCH: 0.0300
# time taken: 1.28s
# validation loss: 0.030766507311188903
# Done with EPOCH
# EPOCH 423
# loss at end of EPOCH: 0.0300
# time taken: 1.32s
# validation loss: 0.030732764345979924
# Done with EPOCH
# EPOCH 424
# loss at end of EPOCH: 0.0300
# time taken: 1.29s
# validation loss: 0.030699040280580927
# Done with EPOCH
# EPOCH 425
# loss at end of EPOCH: 0.0300
# time taken: 1.28s
# validation loss: 0.030665335340808026
# Done with EPOCH
# EPOCH 426
# loss at end of EPOCH: 0.0299
# time taken: 1.27s
# validation loss: 0.03063164975248228
# Done with EPOCH
# EPOCH 427
# loss at end of EPOCH: 0.0299
# time taken: 1.29s
# validation loss: 0.030597983741422728
# Done with EPOCH
# EPOCH 428
# loss at end of EPOCH: 0.0299
# time taken: 1.28s
# validation loss: 0.030564337533440494
# Done with EPOCH
# EPOCH 429
# loss at end of EPOCH: 0.0299
# time taken: 1.28s
# validation loss: 0.030530711354332486
# Done with EPOCH
# EPOCH 430
# loss at end of EPOCH: 0.0299
# time taken: 1.29s
# validation loss: 0.030497105429874678
# Done with EPOCH
# EPOCH 431
# loss at end of EPOCH: 0.0298
# time taken: 1.27s
# validation loss: 0.03046351998581553
# Done with EPOCH
# EPOCH 432
# loss at end of EPOCH: 0.0298
# time taken: 1.27s
# validation loss: 0.030429955247869463
# Done with EPOCH
# EPOCH 433
# loss at end of EPOCH: 0.0298
# time taken: 1.25s
# validation loss: 0.030396411441711013
# Done with EPOCH
# EPOCH 434
# loss at end of EPOCH: 0.0298
# time taken: 1.27s
# validation loss: 0.030362888792967925
# Done with EPOCH
# EPOCH 435
# loss at end of EPOCH: 0.0298
# time taken: 1.29s
# validation loss: 0.030329387527214445
# Done with EPOCH
# EPOCH 436
# ...
# time taken: 1.26s
# validation loss: 0.020235096995026482
# Done with EPOCH
# EPOCH 856
# loss at end of EPOCH: 0.0239
# time taken: 1.30s
# validation loss: 0.020222725772235276
# Done with EPOCH
# EPOCH 857
# loss at end of EPOCH: 0.0239
# time taken: 1.26s
# validation loss: 0.020210405534059925
# Done with EPOCH
# EPOCH 858
# loss at end of EPOCH: 0.0239
# time taken: 1.29s
# validation loss: 0.02019813615821472
# Done with EPOCH
# EPOCH 859
# loss at end of EPOCH: 0.0238
# time taken: 1.26s
# validation loss: 0.02018591752192872
# Done with EPOCH
# EPOCH 860
# loss at end of EPOCH: 0.0238
# time taken: 1.28s
# validation loss: 0.020173749501951103
# Done with EPOCH
# EPOCH 861
# loss at end of EPOCH: 0.0238
# time taken: 1.31s
# validation loss: 0.02016163197455819
# Done with EPOCH
# EPOCH 862
# loss at end of EPOCH: 0.0238
# time taken: 1.25s
# validation loss: 0.020149564815559226
# Done with EPOCH
# EPOCH 863
# loss at end of EPOCH: 0.0238
# time taken: 1.30s
# validation loss: 0.020137547900303067
# Done with EPOCH
# EPOCH 864
# loss at end of EPOCH: 0.0238
# time taken: 1.29s
# validation loss: 0.020125581103684384
# Done with EPOCH
# EPOCH 865
# loss at end of EPOCH: 0.0238
# time taken: 1.28s
# validation loss: 0.0201136643001496
# Done with EPOCH
# EPOCH 866
# loss at end of EPOCH: 0.0238
# time taken: 1.27s
# validation loss: 0.020101797363703624
# Done with EPOCH
# EPOCH 867
# loss at end of EPOCH: 0.0238
# time taken: 1.26s
# validation loss: 0.020089980167916067
# Done with EPOCH
# EPOCH 868
# loss at end of EPOCH: 0.0238
# time taken: 1.28s
# validation loss: 0.02007821258592725
# Done with EPOCH
# EPOCH 869
# loss at end of EPOCH: 0.0238
# time taken: 1.28s
# validation loss: 0.020066494490454886
# Done with EPOCH
# EPOCH 870
# loss at end of EPOCH: 0.0238
# time taken: 1.27s
# validation loss: 0.02005482575380001
# Done with EPOCH
# EPOCH 871
# loss at end of EPOCH: 0.0238
# time taken: 1.27s
# validation loss: 0.02004320624785363
# Done with EPOCH
# EPOCH 872
# loss at end of EPOCH: 0.0238
# time taken: 1.28s
# validation loss: 0.02003163584410282
# Done with EPOCH
# EPOCH 873
# loss at end of EPOCH: 0.0238
# time taken: 1.29s
# validation loss: 0.020020114413636866
# Done with EPOCH
# EPOCH 874
# loss at end of EPOCH: 0.0238
# time taken: 1.31s
# validation loss: 0.0200086418271541
# Done with EPOCH
# EPOCH 875
# loss at end of EPOCH: 0.0238
# time taken: 1.30s
# validation loss: 0.019997217954967436
# Done with EPOCH
# EPOCH 876
# loss at end of EPOCH: 0.0238
# time taken: 1.27s
# validation loss: 0.01998584266701108
# Done with EPOCH
# EPOCH 877
# loss at end of EPOCH: 0.0237
# time taken: 1.30s
# validation loss: 0.019974515832847015
# Done with EPOCH
# EPOCH 878
# loss at end of EPOCH: 0.0237
# time taken: 1.28s
# validation loss: 0.01996323732167082
# Done with EPOCH
# EPOCH 879
# loss at end of EPOCH: 0.0237
# time taken: 1.28s
# validation loss: 0.019952007002318146
# Done with EPOCH
# EPOCH 880
# loss at end of EPOCH: 0.0237
# time taken: 1.27s
# validation loss: 0.019940824743270972
# Done with EPOCH
# EPOCH 881
# loss at end of EPOCH: 0.0237
# time taken: 1.27s
# validation loss: 0.019929690412663854
# Done with EPOCH
# EPOCH 882
# loss at end of EPOCH: 0.0237
# time taken: 1.30s
# validation loss: 0.019918603878290114
# Done with EPOCH
# EPOCH 883
# loss at end of EPOCH: 0.0237
# time taken: 1.28s
# validation loss: 0.019907565007608225
# Done with EPOCH
# EPOCH 884
# loss at end of EPOCH: 0.0237
# time taken: 1.28s
# validation loss: 0.01989657366774798
# Done with EPOCH
# EPOCH 885
# loss at end of EPOCH: 0.0237
# time taken: 1.30s
# validation loss: 0.019885629725516538
# Done with EPOCH
# EPOCH 886
# loss at end of EPOCH: 0.0237
# time taken: 1.29s
# validation loss: 0.019874733047404877
# Done with EPOCH
# EPOCH 887
# loss at end of EPOCH: 0.0237
# time taken: 1.29s
# validation loss: 0.01986388349959397
# Done with EPOCH
# EPOCH 888
# loss at end of EPOCH: 0.0237
# time taken: 1.27s
# validation loss: 0.019853080947960792
# Done with EPOCH
# EPOCH 889
# loss at end of EPOCH: 0.0237
# time taken: 1.29s
# validation loss: 0.01984232525808473
# Done with EPOCH
# EPOCH 890
# loss at end of EPOCH: 0.0237
# time taken: 1.31s
# validation loss: 0.01983161629525364
# Done with EPOCH
# EPOCH 891
# loss at end of EPOCH: 0.0237
# time taken: 1.27s
# validation loss: 0.01982095392447017
# Done with EPOCH
# EPOCH 892
# loss at end of EPOCH: 0.0237
# time taken: 1.27s
# validation loss: 0.01981033801045746
# Done with EPOCH
# EPOCH 893
# loss at end of EPOCH: 0.0237
# time taken: 1.28s
# validation loss: 0.019799768417666057
# Done with EPOCH
# EPOCH 894
# loss at end of EPOCH: 0.0237
# time taken: 1.30s
# validation loss: 0.019789245010279413
# Done with EPOCH
# EPOCH 895
# loss at end of EPOCH: 0.0237
# time taken: 1.26s
# validation loss: 0.01977876765221989
# Done with EPOCH
# EPOCH 896
# loss at end of EPOCH: 0.0237
# time taken: 1.29s
# validation loss: 0.01976833620715563
# Done with EPOCH
# EPOCH 897
# loss at end of EPOCH: 0.0236
# time taken: 1.28s
# validation loss: 0.019757950538505972
# Done with EPOCH
# EPOCH 898
# loss at end of EPOCH: 0.0236
# time taken: 1.30s
# validation loss: 0.01974761050944771
# Done with EPOCH
# EPOCH 899
# loss at end of EPOCH: 0.0236
# time taken: 1.29s
# validation loss: 0.019737315982921194
# Done with EPOCH
# EPOCH 900
# loss at end of EPOCH: 0.0236
# time taken: 1.29s
# validation loss: 0.019727066821636486
# Done with EPOCH
# EPOCH 901
# loss at end of EPOCH: 0.0236
# time taken: 1.26s
# validation loss: 0.019716862888078987
# Done with EPOCH
# EPOCH 902
# loss at end of EPOCH: 0.0236
# time taken: 1.27s
# validation loss: 0.019706704044516105
# Done with EPOCH
# EPOCH 903
# loss at end of EPOCH: 0.0236
# time taken: 1.26s
# validation loss: 0.019696590153002517
# Done with EPOCH
# EPOCH 904
# loss at end of EPOCH: 0.0236
# time taken: 1.28s
# validation loss: 0.019686521075386692
# Done with EPOCH
# EPOCH 905
# loss at end of EPOCH: 0.0236
# time taken: 1.26s
# validation loss: 0.019676496673316838
# Done with EPOCH
# EPOCH 906
# loss at end of EPOCH: 0.0236
# time taken: 1.27s
# validation loss: 0.019666516808246215
# Done with EPOCH
# EPOCH 907
# loss at end of EPOCH: 0.0236
# time taken: 1.26s
# validation loss: 0.01965658134144002
# Done with EPOCH
# EPOCH 908
# loss at end of EPOCH: 0.0236
# time taken: 1.27s
# validation loss: 0.019646690133980516
# Done with EPOCH
# EPOCH 909
# loss at end of EPOCH: 0.0236
# time taken: 1.26s
# validation loss: 0.01963684304677339
# Done with EPOCH
# EPOCH 910
# loss at end of EPOCH: 0.0236
# time taken: 1.28s
# validation loss: 0.019627039940553256
# Done with EPOCH
# EPOCH 911
# loss at end of EPOCH: 0.0236
# time taken: 1.30s
# validation loss: 0.019617280675889998
# Done with EPOCH
# EPOCH 912
# loss at end of EPOCH: 0.0236
# time taken: 1.26s
# validation loss: 0.019607565113194
# Done with EPOCH
# EPOCH 913
# loss at end of EPOCH: 0.0236
# time taken: 1.27s
# validation loss: 0.01959789311272241
# Done with EPOCH
# EPOCH 914
# loss at end of EPOCH: 0.0236
# time taken: 1.28s
# validation loss: 0.019588264534584857
# Done with EPOCH
# EPOCH 915
# loss at end of EPOCH: 0.0236
# time taken: 1.27s
# validation loss: 0.019578679238748908
# Done with EPOCH
# EPOCH 916
# loss at end of EPOCH: 0.0236
# time taken: 1.25s
# validation loss: 0.0195691370850463
# Done with EPOCH
# EPOCH 917
# loss at end of EPOCH: 0.0236
# time taken: 1.28s
# validation loss: 0.019559637933178404
# Done with EPOCH
# EPOCH 918
# loss at end of EPOCH: 0.0236
# time taken: 1.25s
# validation loss: 0.019550181642721733
# Done with EPOCH
# EPOCH 919
# loss at end of EPOCH: 0.0235
# time taken: 1.27s
# validation loss: 0.01954076807313404
# Done with EPOCH
# EPOCH 920
# loss at end of EPOCH: 0.0235
# time taken: 1.27s
# validation loss: 0.01953139708375962
# Done with EPOCH
# EPOCH 921
# loss at end of EPOCH: 0.0235
# time taken: 1.30s
# validation loss: 0.019522068533835254
# Done with EPOCH
# EPOCH 922
# loss at end of EPOCH: 0.0235
# time taken: 1.30s
# validation loss: 0.019512782282495547
# Done with EPOCH
# EPOCH 923
# loss at end of EPOCH: 0.0235
# time taken: 1.28s
# validation loss: 0.019503538188778674
# Done with EPOCH
# EPOCH 924
# loss at end of EPOCH: 0.0235
# time taken: 1.30s
# validation loss: 0.019494336111631688
# Done with EPOCH
# EPOCH 925
# loss at end of EPOCH: 0.0235
# time taken: 1.29s
# validation loss: 0.019485175909916566
# Done with EPOCH
# EPOCH 926
# loss at end of EPOCH: 0.0235
# time taken: 1.28s
# validation loss: 0.01947605744241536
# Done with EPOCH
# EPOCH 927
# loss at end of EPOCH: 0.0235
# time taken: 1.27s
# validation loss: 0.019466980567835523
# Done with EPOCH
# EPOCH 928
# loss at end of EPOCH: 0.0235
# time taken: 1.26s
# validation loss: 0.019457945144815584
# Done with EPOCH
# EPOCH 929
# loss at end of EPOCH: 0.0235
# time taken: 1.27s
# validation loss: 0.019448951031930943
# Done with EPOCH
# EPOCH 930
# loss at end of EPOCH: 0.0235
# time taken: 1.29s
# validation loss: 0.01943999808769847
# Done with EPOCH
# EPOCH 931
# loss at end of EPOCH: 0.0235
# time taken: 1.27s
# validation loss: 0.019431086170582552
# Done with EPOCH
# EPOCH 932
# loss at end of EPOCH: 0.0235
# time taken: 1.25s
# validation loss: 0.019422215139000203
# Done with EPOCH
# EPOCH 933
# loss at end of EPOCH: 0.0235
# time taken: 1.27s
# validation loss: 0.01941338485132623
# Done with EPOCH
# EPOCH 934
# loss at end of EPOCH: 0.0235
# time taken: 1.26s
# validation loss: 0.01940459516589899
# Done with EPOCH
# EPOCH 935
# loss at end of EPOCH: 0.0235
# time taken: 1.29s
# validation loss: 0.019395845941025197
# Done with EPOCH
# EPOCH 936
# loss at end of EPOCH: 0.0235
# time taken: 1.30s
# validation loss: 0.01938713703498512
# Done with EPOCH
# EPOCH 937
# loss at end of EPOCH: 0.0235
# time taken: 1.28s
# validation loss: 0.01937846830603852
# Done with EPOCH
# EPOCH 938
# loss at end of EPOCH: 0.0235
# time taken: 1.28s
# validation loss: 0.01936983961242886
# Done with EPOCH
# EPOCH 939
# loss at end of EPOCH: 0.0235
# time taken: 1.28s
# validation loss: 0.019361250812389097
# Done with EPOCH
# EPOCH 940
# loss at end of EPOCH: 0.0235
# time taken: 1.29s
# validation loss: 0.01935270176414672
# Done with EPOCH
# EPOCH 941
# loss at end of EPOCH: 0.0235
# time taken: 1.27s
# validation loss: 0.019344192325928586
# Done with EPOCH
# EPOCH 942
# loss at end of EPOCH: 0.0235
# time taken: 1.27s
# validation loss: 0.01933572235596614
# Done with EPOCH
# EPOCH 943
# loss at end of EPOCH: 0.0235
# time taken: 1.28s
# validation loss: 0.01932729171250075
# Done with EPOCH
# EPOCH 944
# loss at end of EPOCH: 0.0234
# time taken: 1.26s
# validation loss: 0.019318900253787977
# Done with EPOCH
# EPOCH 945
# loss at end of EPOCH: 0.0234
# time taken: 1.25s
# validation loss: 0.019310547838103282
# Done with EPOCH
# EPOCH 946
# loss at end of EPOCH: 0.0234
# time taken: 1.28s
# validation loss: 0.019302234323746763
# Done with EPOCH
# EPOCH 947
# loss at end of EPOCH: 0.0234
# time taken: 1.30s
# validation loss: 0.019293959569047676
# Done with EPOCH
# EPOCH 948
# loss at end of EPOCH: 0.0234
# time taken: 1.26s
# validation loss: 0.019285723432369797
# Done with EPOCH
# EPOCH 949
# loss at end of EPOCH: 0.0234
# time taken: 1.29s
# validation loss: 0.019277525772115958
# Done with EPOCH
# EPOCH 950
# loss at end of EPOCH: 0.0234
# time taken: 1.29s
# validation loss: 0.01926936644673318
# Done with EPOCH
# EPOCH 951
# loss at end of EPOCH: 0.0234
# time taken: 1.27s
# validation loss: 0.01926124531471703
# Done with EPOCH
# EPOCH 952
# loss at end of EPOCH: 0.0234
# time taken: 1.26s
# validation loss: 0.01925316223461695
# Done with EPOCH
# EPOCH 953
# loss at end of EPOCH: 0.0234
# time taken: 1.28s
# validation loss: 0.01924511706504024
# Done with EPOCH
# EPOCH 954
# loss at end of EPOCH: 0.0234
# time taken: 1.28s
# validation loss: 0.019237109664657286
# Done with EPOCH
# EPOCH 955
# loss at end of EPOCH: 0.0234
# time taken: 1.28s
# validation loss: 0.019229139892206325
# Done with EPOCH
# EPOCH 956
# loss at end of EPOCH: 0.0234
# time taken: 1.26s
# validation loss: 0.019221207606497263
# Done with EPOCH
# EPOCH 957
# loss at end of EPOCH: 0.0234
# time taken: 1.28s
# validation loss: 0.019213312666417248
# Done with EPOCH
# EPOCH 958
# loss at end of EPOCH: 0.0234
# time taken: 1.25s
# validation loss: 0.01920545493093463
# Done with EPOCH
# EPOCH 959
# loss at end of EPOCH: 0.0234
# time taken: 1.24s
# validation loss: 0.019197634259103497
# Done with EPOCH
# EPOCH 960
# loss at end of EPOCH: 0.0234
# time taken: 1.28s
# validation loss: 0.01918985051006848
# Done with EPOCH
# EPOCH 961
# loss at end of EPOCH: 0.0234
# time taken: 1.29s
# validation loss: 0.019182103543069
# Done with EPOCH
# EPOCH 962
# loss at end of EPOCH: 0.0234
# time taken: 1.28s
# validation loss: 0.01917439321744342
# Done with EPOCH
# EPOCH 963
# loss at end of EPOCH: 0.0234
# time taken: 1.27s
# validation loss: 0.019166719392633966
# Done with EPOCH
# EPOCH 964
# loss at end of EPOCH: 0.0234
# time taken: 1.27s
# validation loss: 0.019159081928190717
# Done with EPOCH
# EPOCH 965
# loss at end of EPOCH: 0.0234
# time taken: 1.26s
# validation loss: 0.01915148068377609
# Done with EPOCH
# EPOCH 966
# loss at end of EPOCH: 0.0234
# time taken: 1.29s
# validation loss: 0.019143915519169018
# Done with EPOCH
# EPOCH 967
# loss at end of EPOCH: 0.0234
# time taken: 1.29s
# validation loss: 0.019136386294268906
# Done with EPOCH
# EPOCH 968
# loss at end of EPOCH: 0.0234
# time taken: 1.27s
# validation loss: 0.019128892869100605
# Done with EPOCH
# EPOCH 969
# loss at end of EPOCH: 0.0234
# time taken: 1.30s
# validation loss: 0.01912143510381789
# Done with EPOCH
# EPOCH 970
# loss at end of EPOCH: 0.0234
# time taken: 1.26s
# validation loss: 0.019114012858708014
# Done with EPOCH
# EPOCH 971
# loss at end of EPOCH: 0.0234
# time taken: 1.30s
# validation loss: 0.01910662599419522
# Done with EPOCH
# EPOCH 972
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.019099274370845593
# Done with EPOCH
# EPOCH 973
# loss at end of EPOCH: 0.0233
# time taken: 1.27s
# validation loss: 0.019091957849370667
# Done with EPOCH
# EPOCH 974
# loss at end of EPOCH: 0.0233
# time taken: 1.30s
# validation loss: 0.019084676290631326
# Done with EPOCH
# EPOCH 975
# loss at end of EPOCH: 0.0233
# time taken: 1.29s
# validation loss: 0.019077429555642143
# Done with EPOCH
# EPOCH 976
# loss at end of EPOCH: 0.0233
# time taken: 1.27s
# validation loss: 0.01907021750557479
# Done with EPOCH
# EPOCH 977
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.019063040001762514
# Done with EPOCH
# EPOCH 978
# loss at end of EPOCH: 0.0233
# time taken: 1.26s
# validation loss: 0.01905589690570333
# Done with EPOCH
# EPOCH 979
# loss at end of EPOCH: 0.0233
# time taken: 1.29s
# validation loss: 0.019048788079064568
# Done with EPOCH
# EPOCH 980
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.01904171338368606
# Done with EPOCH
# EPOCH 981
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.01903467268158409
# Done with EPOCH
# EPOCH 982
# loss at end of EPOCH: 0.0233
# time taken: 1.29s
# validation loss: 0.019027665834955274
# Done with EPOCH
# EPOCH 983
# loss at end of EPOCH: 0.0233
# time taken: 1.30s
# validation loss: 0.01902069270618002
# Done with EPOCH
# EPOCH 984
# loss at end of EPOCH: 0.0233
# time taken: 1.29s
# validation loss: 0.019013753157826083
# Done with EPOCH
# EPOCH 985
# loss at end of EPOCH: 0.0233
# time taken: 1.27s
# validation loss: 0.0190068470526525
# Done with EPOCH
# EPOCH 986
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.018999974253612953
# Done with EPOCH
# EPOCH 987
# loss at end of EPOCH: 0.0233
# time taken: 1.26s
# validation loss: 0.018993134623858945
# Done with EPOCH
# EPOCH 988
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.01898632802674409
# Done with EPOCH
# EPOCH 989
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.018979554325826938
# Done with EPOCH
# EPOCH 990
# loss at end of EPOCH: 0.0233
# time taken: 1.30s
# validation loss: 0.018972813384874627
# Done with EPOCH
# EPOCH 991
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.01896610506786611
# Done with EPOCH
# EPOCH 992
# loss at end of EPOCH: 0.0233
# time taken: 1.29s
# validation loss: 0.018959429238995733
# Done with EPOCH
# EPOCH 993
# loss at end of EPOCH: 0.0233
# time taken: 1.26s
# validation loss: 0.018952785762676363
# Done with EPOCH
# EPOCH 994
# loss at end of EPOCH: 0.0233
# time taken: 1.27s
# validation loss: 0.018946174503542655
# Done with EPOCH
# EPOCH 995
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.018939595326454374
# Done with EPOCH
# EPOCH 996
# loss at end of EPOCH: 0.0233
# time taken: 1.32s
# validation loss: 0.01893304809649962
# Done with EPOCH
# EPOCH 997
# loss at end of EPOCH: 0.0233
# time taken: 1.28s
# validation loss: 0.018926532678997975
# Done with EPOCH
# EPOCH 998
# loss at end of EPOCH: 0.0233
# time taken: 1.30s
# validation loss: 0.018920048939503404
# Done with EPOCH
# EPOCH 999
# loss at end of EPOCH: 0.0233
# time taken: 1.29s
# validation loss: 0.018913596743807742
# Done with EPOCH

# %%
test_data = data[1000:1150]
test_data,_,_ = normalize(test_data, train_mean, train_std)
x_test, y_test = seperate_labels(test_data, 4, 1)
print(x_test.shape, y_test.shape)
y_predict = rnn_forward(x_test, h_ini, Wxh, bh, Whh, Why, by)

print(y_predict.shape)
y_test = inverse_transform(y_test, train_mean, train_std)
y_predict = inverse_transform(y_predict, train_mean, train_std)
final = np.hstack([y_test, y_predict])
print(final)
loss = tf.math.sqrt(tf.reduce_sum(tf.math.square(y_predict-y_test))/len(x_test))
print("Test error: ", loss.numpy())
# Out:
# (146, 3, 2) (146, 2)
# (146, 2)
# [[32.22222222 23.33333333 32.7182184  23.40876544]
#  [35.         23.88888889 32.97545426 23.59371282]
#  [33.33333333 23.88888889 31.96394459 23.05897152]
#  [33.88888889 23.33333333 33.17039202 23.63791889]
#  [34.44444444 25.         32.60018656 23.36744522]
#  [34.44444444 25.55555556 32.6645815  23.38822343]
#  [33.88888889 25.55555556 33.23294149 23.68606854]
#  [33.33333333 27.77777778 33.41618068 23.77445464]
#  [33.33333333 26.66666667 33.2067619  23.67764296]
#  [34.44444444 23.88888889 33.35966076 23.79629051]
#  [33.88888889 24.44444444 33.18268379 23.68660289]
#  [33.33333333 25.         33.09808355 23.59068029]
#  [34.44444444 25.         32.94344183 23.5389305 ]
#  [32.77777778 23.88888889 32.79477614 23.48254988]
#  [33.88888889 24.44444444 33.25735744 23.69288269]
#  [33.88888889 25.55555556 32.36579344 23.25799119]
#  [30.         22.77777778 32.85299804 23.50155729]
#  [32.77777778 22.22222222 33.13107453 23.64812822]
#  [33.88888889 23.88888889 30.77103124 22.49971999]
#  [34.44444444 24.44444444 31.66527124 22.91882333]
#  [33.88888889 23.88888889 32.64431793 23.40002927]
#  [33.33333333 23.88888889 33.1338825  23.62642119]
#  [31.11111111 22.77777778 32.84579304 23.47920792]
#  [32.77777778 22.77777778 32.55819001 23.35114539]
#  [32.22222222 23.88888889 31.23451488 22.72004138]
#  [33.33333333 25.55555556 31.85008322 23.0132599 ]
#  [32.22222222 21.66666667 31.90938939 23.06245937]
#  [28.33333333 21.66666667 32.77337329 23.49170664]
#  [33.33333333 21.66666667 31.57182618 22.83999528]
#  [31.66666667 23.33333333 29.3599948  21.84690876]
#  [33.33333333 24.44444444 31.61135283 22.89030659]
#  [32.77777778 24.44444444 31.48827894 22.85963762]
#  [32.22222222 24.44444444 32.50016778 23.3453463 ]
#  [35.         24.44444444 32.37974013 23.28216019]
#  [34.44444444 24.44444444 32.10846647 23.16014429]
#  [32.77777778 24.44444444 33.30055381 23.70522782]
#  [32.77777778 23.88888889 33.21214786 23.65810829]
#  [31.66666667 23.88888889 32.47259522 23.32154819]
#  [32.22222222 23.33333333 32.2586693  23.21522443]
#  [31.11111111 23.88888889 31.70549088 22.96516977]
#  [31.66666667 23.88888889 31.77732831 22.98732585]
#  [32.77777778 23.33333333 31.36782087 22.81526048]
#  [32.77777778 23.88888889 31.58581958 22.91537415]
#  [33.33333333 23.88888889 32.02439201 23.10039234]
#  [33.88888889 23.33333333 32.19731813 23.1917282 ]
#  [33.88888889 23.33333333 32.4765401  23.31675677]
#  [33.88888889 23.88888889 32.64791969 23.38080867]
#  [32.77777778 23.33333333 32.66695047 23.39004471]
#  [33.88888889 23.88888889 32.78017917 23.45446215]
#  [33.33333333 23.88888889 32.18340826 23.16641042]
#  [33.33333333 21.66666667 32.71772115 23.42904742]
#  [30.55555556 22.22222222 32.5419357  23.34364421]
#  [31.66666667 22.77777778 32.05842742 23.07030431]
#  [31.11111111 23.33333333 30.74463692 22.49107126]
#  [31.11111111 22.22222222 31.24274535 22.73943676]
#  [32.22222222 22.22222222 31.16708321 22.71343592]
#  [31.11111111 23.88888889 30.91222078 22.56741208]
#  [32.22222222 22.77777778 31.41784528 22.8041888 ]
#  [32.22222222 22.22222222 31.31369467 22.79508709]
#  [32.22222222 22.77777778 31.60789647 22.89731354]
#  [30.55555556 22.77777778 31.51799789 22.84412638]
#  [32.77777778 22.22222222 31.62486738 22.90901573]
#  [32.22222222 22.77777778 30.81894929 22.538066  ]
#  [32.22222222 22.77777778 31.6769997  22.92185306]
#  [32.22222222 21.66666667 31.64626781 22.91725108]
#  [31.11111111 23.88888889 31.64780791 22.9168857 ]
#  [31.11111111 23.88888889 31.40098574 22.77590102]
#  [31.66666667 22.77777778 31.30593563 22.79406949]
#  [31.11111111 23.33333333 31.30752655 22.78813762]
#  [31.11111111 24.44444444 31.33427998 22.7727617 ]
#  [32.22222222 22.77777778 31.1804268  22.71994219]
#  [30.55555556 23.88888889 31.40773019 22.85063447]
#  [31.66666667 23.33333333 31.62224736 22.90192106]
#  [28.88888889 23.88888889 31.06903859 22.68188054]
#  [30.         24.44444444 31.42380546 22.82908765]
#  [31.11111111 23.33333333 30.18622979 22.27946559]
#  [29.44444444 23.33333333 30.71186121 22.53956316]
#  [29.44444444 22.22222222 31.10156973 22.68204994]
#  [31.11111111 22.77777778 30.30269615 22.31950852]
#  [30.         23.88888889 29.9156301  22.11784547]
#  [27.22222222 23.33333333 30.8469387  22.56369502]
#  [29.44444444 23.33333333 30.67914364 22.50772009]
#  [27.77777778 21.11111111 29.0399814  21.74514201]
#  [27.77777778 21.11111111 29.98596967 22.1891826 ]
#  [29.44444444 21.11111111 28.67265544 21.51846586]
#  [29.44444444 21.11111111 28.44531297 21.433827  ]
#  [28.88888889 21.11111111 29.34316329 21.84323922]
#  [28.88888889 23.33333333 29.49066172 21.90389067]
#  [28.88888889 22.22222222 29.20759544 21.77421429]
#  [30.         23.88888889 29.70441537 22.06587654]
#  [29.44444444 23.33333333 29.52988921 21.94325681]
#  [28.33333333 22.22222222 30.4805433  22.42852081]
#  [28.33333333 22.77777778 30.21583066 22.28045133]
#  [30.         20.55555556 29.30217873 21.83817057]
#  [32.77777778 21.66666667 29.28276025 21.85538413]
#  [28.88888889 20.55555556 29.65160484 21.95740393]
#  [27.22222222 23.33333333 31.38515711 22.78713042]
#  [28.33333333 22.77777778 29.37125032 21.81714981]
#  [25.55555556 22.77777778 28.80234779 21.6590674 ]
#  [28.33333333 21.66666667 29.21238989 21.82049925]
#  [28.33333333 22.22222222 27.69284866 21.12917128]
#  [27.22222222 22.22222222 28.75852012 21.5925813 ]
#  [28.88888889 22.22222222 29.06065307 21.74182004]
#  [28.33333333 21.66666667 28.49338126 21.47929541]
#  [27.77777778 22.22222222 29.3310506  21.86571423]
#  [26.11111111 22.22222222 29.01830135 21.70055305]
#  [27.77777778 20.55555556 28.79288459 21.61909363]
#  [28.33333333 21.66666667 27.79774805 21.16478056]
#  [27.77777778 22.22222222 28.16773912 21.29071431]
#  [28.33333333 22.22222222 28.81878348 21.62399626]
#  [27.22222222 21.11111111 28.7663299  21.60645153]
#  [28.33333333 21.11111111 29.06998411 21.74427502]
#  [28.88888889 22.22222222 28.20233167 21.31371851]
#  [26.66666667 22.22222222 28.68666493 21.54613971]
#  [27.22222222 22.77777778 29.35432082 21.87782813]
#  [29.44444444 22.22222222 28.22136209 21.35284857]
#  [26.11111111 21.11111111 28.49123855 21.50184774]
#  [27.22222222 21.66666667 29.63798402 22.00270008]
#  [25.         21.66666667 27.65169212 21.05790086]
#  [25.55555556 22.22222222 28.10145615 21.30052286]
#  [26.11111111 21.66666667 26.86431791 20.72839893]
#  [26.66666667 22.22222222 27.14287625 20.88283412]
#  [27.77777778 21.11111111 27.37784956 20.96679744]
#  [27.77777778 22.22222222 27.89185138 21.21898943]
#  [28.33333333 21.11111111 28.33618749 21.38189317]
#  [27.22222222 22.22222222 28.68189217 21.57448351]
#  [26.11111111 22.22222222 28.77838371 21.57871426]
#  [26.66666667 21.66666667 28.43357983 21.45888547]
#  [26.66666667 22.22222222 27.74050491 21.14085038]
#  [26.11111111 20.55555556 27.80262243 21.15777807]
#  [25.55555556 22.22222222 27.95593318 21.24559338]
#  [28.33333333 21.66666667 27.22001481 20.85514695]
#  [27.77777778 22.22222222 27.19087217 20.90710747]
#  [27.22222222 21.11111111 28.68008977 21.55948267]
#  [26.11111111 20.55555556 28.74490171 21.59773979]
#  [27.77777778 22.77777778 28.154901   21.29406587]
#  [28.33333333 22.22222222 27.23746172 20.86773808]
#  [27.22222222 22.22222222 28.63428913 21.57916563]
#  [27.77777778 22.22222222 29.05746536 21.73520464]
#  [30.         20.55555556 28.49271679 21.4795403 ]
#  [28.88888889 21.11111111 28.71043227 21.58299745]
#  [27.77777778 21.11111111 29.56241551 21.92193829]
#  [28.88888889 22.22222222 29.21429057 21.77882857]
#  [28.33333333 22.77777778 28.53786762 21.47014082]
#  [28.33333333 22.77777778 29.32770629 21.86775008]
#  [27.77777778 22.22222222 29.29549174 21.85834578]]
# Test error:  1.8103770843710814

# %%
def lstm_step(x, prev_h, prev_c, Wx, Wh, b):
    
    N, H = prev_c.shape
    
    a = tf.matmul(x, Wx) + tf.matmul(prev_h, Wh) + b
    
    a_f = tf.math.sigmoid(a[:, 0:H])
    
    a_r = tf.math.sigmoid(a[:, H:2*H])
    
    a_s = tf.math.sigmoid(a[:, 2*H:3*H])
    
    a_g = tf.math.tanh(a[:, 3*H:4*H])
    
    next_c = a_f * prev_c + a_r * a_g
    
    next_h = a_s * tf.math.tanh(next_c)
    
    return next_h, next_c

# %%
def lstm_fwd(x, h_ini, c_ini, Wx, Wh, b):
    
    if x.ndim is not 3:
        x = tf.expand_dims(x, 0)
    
    t = x.shape[1]
    h = np.copy(h_ini)
    c = np.copy(c_ini)
    for i in range(t):
        xs = x[:, i, :]
        if xs.ndim is not 2:
            xs = tf.expand_dims(xs, 0)
        h, c = lstm_step(xs, h, c, Wx, Wh, b)
    return h

# %%
def dense(x, W, b):
    return tf.matmul(x, W) + b

# %%
state_size = 4

hl_ini = [[0.]*state_size]
c_ini = [[0.]*state_size]

Wx = tf.Variable(np.random.randn(num_features, state_size*4)*0.1)
Wh = tf.Variable(np.random.randn(state_size, state_size*4)*0.1)
b = tf.Variable(np.random.randn(state_size*4)*0.1)

Wd = tf.Variable(np.random.randn(state_size, out_size)*0.1)
bd = tf.Variable(np.random.randn(out_size)*0.1)

print(Wx, Wh)
# Out:
# <tf.Variable 'Variable:0' shape=(2, 16) dtype=float64, numpy=
# array([[-0.0179505 , -0.0456883 ,  0.03207845, -0.00350919,  0.11529528,
#         -0.0831654 ,  0.02231341,  0.00766288, -0.08454858, -0.08205871,
#          0.07236798, -0.08369838,  0.05452022,  0.01436621,  0.18295203,
#         -0.19371323],
#        [-0.09928285, -0.05749889, -0.02100566, -0.03701541,  0.05499971,
#          0.16422452, -0.06478951,  0.08458764, -0.08421951, -0.16151821,
#          0.03038669, -0.18491711, -0.01923452, -0.12581617, -0.04603581,
#         -0.08954482]])> <tf.Variable 'Variable:0' shape=(4, 16) dtype=float64, numpy=
# array([[ 0.01106962, -0.0892606 , -0.15978592, -0.07802342, -0.05522391,
#         -0.04921418, -0.05005516, -0.04075116,  0.08185176, -0.11827583,
#         -0.04517619, -0.0790738 , -0.01076518, -0.01719981,  0.0244723 ,
#         -0.10020346],
#        [-0.11679509,  0.0813782 ,  0.1115818 , -0.03321786, -0.16517676,
#         -0.08288083, -0.1359995 ,  0.18109243,  0.01130239,  0.11048858,
#         -0.16256526, -0.18326526,  0.09585642, -0.01350351,  0.10221929,
#         -0.10075335],
#        [ 0.07133138,  0.05899708,  0.06397556,  0.12794835, -0.12818231,
#         -0.04797597,  0.12028649,  0.02665899,  0.23879742, -0.01551212,
#          0.06596011, -0.01638123,  0.01234787,  0.18257494,  0.03295454,
#         -0.04154783],
#        [-0.01533455,  0.01604855, -0.18068556, -0.05851012,  0.10814953,
#          0.07175967, -0.04611812,  0.02332684,  0.04169134, -0.04773808,
#         -0.10246172,  0.07656018, -0.11183112,  0.07451185,  0.03457051,
#          0.05693693]])>

# %%
X, Y = seperate_labels(train_data, window=10, step=1)
x_cv, y_cv = seperate_labels(cv_data, 10, 1)

# %%
learning_rate = 0.1
mini_batch = 64
epochs = 100
for i in range(epochs):
    print("EPOCH", i)
    start = time.time()
    total_loss = 0.
    for j in range(0, num_samples-mini_batch, mini_batch):
        xs = X[j:j+mini_batch,:,:]
        ys = Y[j:j+mini_batch]
        with tf.GradientTape(persistent=True, watch_accessed_variables=False) as t:
            t.watch([Wx, Wh, b, Wd, bd])
            out = dense(lstm_fwd(xs, hl_ini, c_ini, Wx, Wh, b), Wd, bd)
            loss = tf.reduce_sum(tf.math.square(out-ys))/mini_batch
            total_loss += loss
        Wx.assign_sub(learning_rate*t.gradient(loss,Wx))
        Wh.assign_sub(learning_rate*t.gradient(loss,Wh))
        b.assign_sub(learning_rate*t.gradient(loss,b))
        Wd.assign_sub(learning_rate*t.gradient(loss,Wd))
        bd.assign_sub(learning_rate*t.gradient(loss,bd))
        del t
    end = time.time()
    mean_loss = total_loss/(num_samples//mini_batch)
    print("loss at end of EPOCH: %0.4f" % mean_loss)
    print("time taken: {:0.2f}s".format(end-start))
    y_predict = dense(lstm_fwd(x_cv, hl_ini, c_ini, Wx, Wh, b), Wd, bd)
    cv_loss = tf.reduce_sum(tf.math.square(y_predict-y_cv))/len(x_cv)
    print("validation loss:", cv_loss.numpy())
    print("Done with EPOCH")
# Out:
# EPOCH 0
# loss at end of EPOCH: 0.0218
# time taken: 0.99s
# validation loss: 0.018230372330047276
# Done with EPOCH
# EPOCH 1
# loss at end of EPOCH: 0.0218
# time taken: 1.11s
# validation loss: 0.018162610505896265
# Done with EPOCH
# EPOCH 2
# loss at end of EPOCH: 0.0217
# time taken: 0.95s
# validation loss: 0.018105535900790212
# Done with EPOCH
# EPOCH 3
# loss at end of EPOCH: 0.0217
# time taken: 0.91s
# validation loss: 0.01805799946096978
# Done with EPOCH
# EPOCH 4
# loss at end of EPOCH: 0.0216
# time taken: 0.92s
# validation loss: 0.018018906413811236
# Done with EPOCH
# EPOCH 5
# loss at end of EPOCH: 0.0216
# time taken: 1.24s
# validation loss: 0.017987231337505443
# Done with EPOCH
# EPOCH 6
# loss at end of EPOCH: 0.0215
# time taken: 0.99s
# validation loss: 0.01796202710943814
# Done with EPOCH
# EPOCH 7
# loss at end of EPOCH: 0.0215
# time taken: 1.31s
# validation loss: 0.017942429110444094
# Done with EPOCH
# EPOCH 8
# loss at end of EPOCH: 0.0215
# time taken: 1.14s
# validation loss: 0.017927655876347242
# Done with EPOCH
# EPOCH 9
# loss at end of EPOCH: 0.0215
# time taken: 1.21s
# validation loss: 0.01791700718608783
# Done with EPOCH
# EPOCH 10
# loss at end of EPOCH: 0.0214
# time taken: 0.93s
# validation loss: 0.017909860382454245
# Done with EPOCH
# EPOCH 11
# loss at end of EPOCH: 0.0214
# time taken: 1.32s
# validation loss: 0.017905665549397147
# Done with EPOCH
# EPOCH 12
# loss at end of EPOCH: 0.0214
# time taken: 0.94s
# validation loss: 0.017903940023636614
# Done with EPOCH
# EPOCH 13
# loss at end of EPOCH: 0.0214
# time taken: 1.48s
# validation loss: 0.01790426259783788
# Done with EPOCH
# EPOCH 14
# loss at end of EPOCH: 0.0214
# time taken: 1.32s
# validation loss: 0.017906267675808777
# Done with EPOCH
# EPOCH 15
# loss at end of EPOCH: 0.0213
# time taken: 1.18s
# validation loss: 0.017909639563812075
# Done with EPOCH
# EPOCH 16
# loss at end of EPOCH: 0.0213
# time taken: 1.07s
# validation loss: 0.01791410702285648
# Done with EPOCH
# EPOCH 17
# loss at end of EPOCH: 0.0213
# time taken: 1.46s
# validation loss: 0.017919438161602134
# Done with EPOCH
# EPOCH 18
# loss at end of EPOCH: 0.0213
# time taken: 1.73s
# validation loss: 0.01792543571553851
# Done with EPOCH
# EPOCH 19
# loss at end of EPOCH: 0.0213
# time taken: 1.32s
# validation loss: 0.017931932733025513
# Done with EPOCH
# EPOCH 20
# loss at end of EPOCH: 0.0213
# time taken: 0.93s
# validation loss: 0.017938788670703903
# Done with EPOCH
# EPOCH 21
# loss at end of EPOCH: 0.0213
# time taken: 0.94s
# validation loss: 0.017945885888101934
# Done with EPOCH
# EPOCH 22
# loss at end of EPOCH: 0.0213
# time taken: 1.60s
# validation loss: 0.01795312652273195
# Done with EPOCH
# EPOCH 23
# loss at end of EPOCH: 0.0213
# time taken: 1.17s
# validation loss: 0.0179604297215737
# Done with EPOCH
# EPOCH 24
# loss at end of EPOCH: 0.0213
# time taken: 0.99s
# validation loss: 0.01796772920178738
# Done with EPOCH
# EPOCH 25
# loss at end of EPOCH: 0.0212
# time taken: 1.00s
# validation loss: 0.017974971112166234
# Done with EPOCH
# EPOCH 26
# loss at end of EPOCH: 0.0212
# time taken: 1.00s
# validation loss: 0.017982112166739624
# Done with EPOCH
# EPOCH 27
# loss at end of EPOCH: 0.0212
# time taken: 0.98s
# validation loss: 0.017989118022703008
# Done with EPOCH
# EPOCH 28
# loss at end of EPOCH: 0.0212
# time taken: 0.97s
# validation loss: 0.017995961876191416
# Done with EPOCH
# EPOCH 29
# loss at end of EPOCH: 0.0212
# time taken: 0.99s
# validation loss: 0.018002623251119076
# Done with EPOCH
# EPOCH 30
# loss at end of EPOCH: 0.0212
# time taken: 0.96s
# validation loss: 0.01800908695821178
# Done with EPOCH
# EPOCH 31
# loss at end of EPOCH: 0.0212
# time taken: 0.98s
# validation loss: 0.018015342203351593
# Done with EPOCH
# EPOCH 32
# loss at end of EPOCH: 0.0212
# time taken: 1.09s
# validation loss: 0.01802138182634466
# Done with EPOCH
# EPOCH 33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-ffa96b3aaa3f> in <module>
#      15             total_loss += loss
#      16         Wx.assign_sub(learning_rate*t.gradient(loss,Wx))
# ---> 17         Wh.assign_sub(learning_rate*t.gradient(loss,Wh))
#      18         b.assign_sub(learning_rate*t.gradient(loss,b))
#      19         Wd.assign_sub(learning_rate*t.gradient(loss,Wd))
#
# ~/anaconda3/envs/GPU/lib/python3.7/site-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#     954         flat_sources,
#     955         output_gradients=output_gradients,
# --> 956         unconnected_gradients=unconnected_gradients)
#     957
#     958     if not self._persistent:
#
# ~/anaconda3/envs/GPU/lib/python3.7/site-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, unconnected_gradients)
#      70       sources,
#      71       output_gradients,
# ---> 72       compat.as_str(unconnected_gradients.value))
#
# ~/anaconda3/envs/GPU/lib/python3.7/site-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads)
#     131     return [None] * num_inputs
#     132
# --> 133   return grad_fn(mock_op, *out_grads)
#     134
#     135
#
# ~/anaconda3/envs/GPU/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py in _MulGrad(op, grad)
#     946   y = math_ops.conj(y)
#     947   return (array_ops.reshape(
# --> 948       math_ops.reduce_sum(gen_math_ops.mul(grad, y), rx), sx),
#     949           array_ops.reshape(
#     950               math_ops.reduce_sum(gen_math_ops.mul(x, grad), ry), sy))
#
# ~/anaconda3/envs/GPU/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/GPU/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in reduce_sum(input_tensor, axis, keepdims, name)
#    1410       gen_math_ops._sum(
#    1411           input_tensor, _ReductionDims(input_tensor, axis), keepdims,
# -> 1412           name=name))
#    1413
#    1414
#
# ~/anaconda3/envs/GPU/lib/python3.7/site-packages/tensorflow/python/ops/gen_math_ops.py in _sum(input, axis, keep_dims, name)
#   10683         _ctx._context_handle, _ctx._thread_local_data.device_name, "Sum",
#   10684         name, _ctx._post_execution_callbacks, input, axis, "keep_dims",
# > 10685         keep_dims)
#   10686       return _result
#   10687     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
test_data = data[1000:1150]
test_data,_,_ = normalize(test_data, train_mean, train_std)
x_test, y_test = seperate_labels(test_data, 10, 1)
print(x_test.shape, y_test.shape)
y_predict = dense(lstm_fwd(x_test, hl_ini, c_ini, Wx, Wh, b), Wd, bd)

print(y_predict.shape)
loss = tf.reduce_sum(tf.math.square(y_predict-y_test))/len(x_test)
print("Test error: ", loss.numpy())
#y_test = inverse_transform(y_test, train_mean, train_std)
#y_predict = inverse_transform(y_predict, train_mean, train_std)
final = np.hstack([y_test, y_predict])
print(final)
loss = tf.math.sqrt(tf.reduce_sum(tf.math.square(y_predict-y_test))/len(x_test))
print("Test error: ", loss.numpy())
# Out:
# (140, 9, 2) (140, 2)
# (140, 2)
# Test error:  0.019143371550185456
# [[1.26259615 1.31703947 1.18350715 1.11102218]
#  [1.22413462 1.52756579 1.19474595 1.11855156]
#  [1.22413462 1.42230263 1.19620398 1.12077009]
#  [1.30105769 1.15914474 1.20237436 1.12795949]
#  [1.26259615 1.21177632 1.2001698  1.12748845]
#  [1.22413462 1.26440789 1.20058549 1.12444641]
#  [1.30105769 1.26440789 1.19620472 1.12122675]
#  [1.18567308 1.15914474 1.19020571 1.11850721]
#  [1.26259615 1.21177632 1.1995178  1.1230714 ]
#  [1.26259615 1.31703947 1.17744942 1.11033739]
#  [0.99336538 1.05388158 1.1824145  1.11260125]
#  [1.18567308 1.00125    1.18904702 1.11710804]
#  [1.26259615 1.15914474 1.12713315 1.08243376]
#  [1.30105769 1.21177632 1.12610653 1.07886265]
#  [1.26259615 1.15914474 1.14522347 1.08873029]
#  [1.22413462 1.15914474 1.16479662 1.09951348]
#  [1.07028846 1.05388158 1.16650077 1.10036074]
#  [1.18567308 1.05388158 1.16161967 1.09809008]
#  [1.14721154 1.15914474 1.12450681 1.07783845]
#  [1.22413462 1.31703947 1.12484162 1.07681202]
#  [1.14721154 0.94861842 1.12067807 1.07511812]
#  [0.87798077 0.94861842 1.14585342 1.09116009]
#  [1.22413462 0.94861842 1.12072917 1.07423521]
#  [1.10875    1.10651316 1.04906355 1.03432825]
#  [1.22413462 1.21177632 1.07657629 1.04617198]
#  [1.18567308 1.21177632 1.07482453 1.04597516]
#  [1.14721154 1.21177632 1.10622122 1.06462926]
#  [1.33951923 1.21177632 1.11844047 1.07286461]
#  [1.30105769 1.21177632 1.1192857  1.0746691 ]
#  [1.18567308 1.21177632 1.15777489 1.09531328]
#  [1.18567308 1.15914474 1.17060144 1.1024716 ]
#  [1.10875    1.15914474 1.16100941 1.09886902]
#  [1.14721154 1.10651316 1.15676225 1.09718901]
#  [1.07028846 1.15914474 1.13726309 1.08705174]
#  [1.10875    1.15914474 1.12998793 1.08215894]
#  [1.18567308 1.10651316 1.1107988  1.0719067 ]
#  [1.18567308 1.15914474 1.10650607 1.06914621]
#  [1.22413462 1.15914474 1.11482215 1.07212662]
#  [1.26259615 1.10651316 1.12064576 1.07497423]
#  [1.26259615 1.10651316 1.13179685 1.08074468]
#  [1.26259615 1.15914474 1.14345019 1.08625368]
#  [1.18567308 1.10651316 1.15101671 1.09015815]
#  [1.26259615 1.15914474 1.15993248 1.09584112]
#  [1.22413462 1.15914474 1.14801073 1.08976519]
#  [1.22413462 0.94861842 1.16044167 1.09702845]
#  [1.03182692 1.00125    1.15923262 1.0968673 ]
#  [1.10875    1.05388158 1.14629947 1.08736442]
#  [1.07028846 1.10651316 1.10364652 1.06443455]
#  [1.07028846 1.00125    1.09571901 1.05985865]
#  [1.14721154 1.00125    1.08291719 1.05311698]
#  [1.07028846 1.15914474 1.06674659 1.04261195]
#  [1.14721154 1.05388158 1.07202506 1.04391913]
#  [1.14721154 1.00125    1.06916971 1.04406877]
#  [1.14721154 1.05388158 1.07584479 1.04668225]
#  [1.03182692 1.05388158 1.07630144 1.04574384]
#  [1.18567308 1.00125    1.08129862 1.04874406]
#  [1.14721154 1.05388158 1.06126411 1.03867672]
#  [1.14721154 1.05388158 1.07822656 1.04677282]
#  [1.14721154 0.94861842 1.0827205  1.04956624]
#  [1.07028846 1.15914474 1.08663732 1.0521046 ]
#  [1.07028846 1.15914474 1.08144933 1.04800707]
#  [1.10875    1.05388158 1.07686292 1.04808025]
#  [1.07028846 1.10651316 1.0736831  1.04760417]
#  [1.07028846 1.21177632 1.0729508  1.04622476]
#  [1.14721154 1.05388158 1.06756073 1.04360384]
#  [1.03182692 1.15914474 1.07273543 1.04818077]
#  [1.10875    1.10651316 1.07987788 1.05033445]
#  [0.91644231 1.15914474 1.06709232 1.04451703]
#  [0.99336538 1.21177632 1.07270789 1.04702845]
#  [1.07028846 1.10651316 1.03733063 1.02890308]
#  [0.95490385 1.10651316 1.0368535  1.02929187]
#  [0.95490385 1.00125    1.04426291 1.03168032]
#  [1.07028846 1.05388158 1.02252864 1.01932801]
#  [0.99336538 1.15914474 1.00139378 1.00563749]
#  [0.80105769 1.10651316 1.01643797 1.01264755]
#  [0.95490385 1.10651316 1.01427134 1.01256358]
#  [0.83951923 0.89598684 0.96519007 0.98601399]
#  [0.83951923 0.89598684 0.96982857 0.98752186]
#  [0.95490385 0.89598684 0.92906185 0.96174315]
#  [0.95490385 0.89598684 0.90059115 0.94327774]
#  [0.91644231 0.89598684 0.90688775 0.94420845]
#  [0.91644231 1.10651316 0.91072207 0.94507495]
#  [0.91644231 1.00125    0.90427568 0.94103089]
#  [0.99336538 1.15914474 0.91411277 0.94885974]
#  [0.95490385 1.10651316 0.91329976 0.94844461]
#  [0.87798077 1.00125    0.94657966 0.96939938]
#  [0.87798077 1.05388158 0.9536584  0.97441785]
#  [0.99336538 0.84335526 0.93574169 0.96439137]
#  [1.18567308 0.94861842 0.9286696  0.96091867]
#  [0.91644231 0.84335526 0.93394391 0.96042705]
#  [0.80105769 1.10651316 0.98917079 0.99016049]
#  [0.87798077 1.05388158 0.95354927 0.97013428]
#  [0.68567308 1.05388158 0.92351342 0.95684399]
#  [0.87798077 0.94861842 0.91853144 0.95438036]
#  [0.87798077 1.00125    0.8656296  0.9252164 ]
#  [0.80105769 1.00125    0.87027882 0.92500376]
#  [0.91644231 1.00125    0.87679187 0.92793554]
#  [0.87798077 0.94861842 0.86187324 0.91952203]
#  [0.83951923 1.00125    0.87972071 0.92878122]
#  [0.72413462 1.00125    0.87489753 0.92501009]
#  [0.83951923 0.84335526 0.87011173 0.92299861]
#  [0.87798077 0.94861842 0.83911473 0.90632453]
#  [0.83951923 1.00125    0.83449404 0.90090941]
#  [0.87798077 1.00125    0.84921283 0.90896911]
#  [0.80105769 0.89598684 0.85149088 0.91102137]
#  [0.87798077 0.89598684 0.86254938 0.91755896]
#  [0.91644231 1.00125    0.84487155 0.90705157]
#  [0.76259615 1.00125    0.85027398 0.9089713 ]
#  [0.80105769 1.05388158 0.8709308  0.921361  ]
#  [0.95490385 1.00125    0.84782607 0.90983758]
#  [0.72413462 0.89598684 0.84785394 0.9110046 ]
#  [0.80105769 0.94861842 0.88077454 0.92877152]
#  [0.64721154 0.94861842 0.83800381 0.90432838]
#  [0.68567308 1.00125    0.83247094 0.90062091]
#  [0.72413462 0.94861842 0.79051142 0.87711393]
#  [0.76259615 1.00125    0.77607532 0.86883524]
#  [0.83951923 0.89598684 0.77045494 0.86429177]
#  [0.83951923 1.00125    0.77757299 0.86773492]
#  [0.87798077 0.89598684 0.79530129 0.87611007]
#  [0.80105769 1.00125    0.81361195 0.88713525]
#  [0.72413462 1.00125    0.82678101 0.89364236]
#  [0.76259615 0.94861842 0.82790089 0.89613119]
#  [0.76259615 1.00125    0.80972666 0.88718632]
#  [0.72413462 0.84335526 0.80531672 0.88445281]
#  [0.68567308 1.00125    0.80496239 0.88458885]
#  [0.87798077 0.94861842 0.78488403 0.87162634]
#  [0.83951923 1.00125    0.77123231 0.86463366]
#  [0.80105769 0.89598684 0.80344673 0.88129245]
#  [0.72413462 0.84335526 0.8190951  0.89070411]
#  [0.83951923 1.05388158 0.81378937 0.88722742]
#  [0.87798077 1.00125    0.78910995 0.87272347]
#  [0.80105769 1.00125    0.81459404 0.88846675]
#  [0.83951923 1.00125    0.8376812  0.90192083]
#  [0.99336538 0.84335526 0.83501465 0.90145884]
#  [0.91644231 0.89598684 0.8445017  0.90737944]
#  [0.83951923 0.89598684 0.87645892 0.92314353]
#  [0.91644231 1.00125    0.88067345 0.9256322 ]
#  [0.87798077 1.05388158 0.86571223 0.91775581]
#  [0.87798077 1.05388158 0.88335231 0.92893253]
#  [0.83951923 1.00125    0.89095212 0.93523095]]
# Test error:  0.13835957339550253
